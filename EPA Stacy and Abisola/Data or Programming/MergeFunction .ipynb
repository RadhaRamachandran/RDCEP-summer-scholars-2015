# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib
matplotlib.style.use('ggplot')
import glob
import datetime
import matplotlib.dates as mdates
from array import *

# %%
#I had to define the filepath of WolfCreek1968.csv b/c it's not in the same folder as this notebook
#WolfCreek1968.csv is the csv file I created in 'Merging and Sorting DataFrames with Wolf Creek Water Data (1968)
WolfCreek1968 = pd.read_csv(r'/Users/aolawale/Downloads/WolfCreek1968.csv')
#If you check 'Merging and Sorting DataFrames with Wolf Creek Water Data (1968), you'll see I already used this
#but I'm using this again. That's because I saved WolfCreek1968 as a csv before I added this, so the numbers saved as double digits
WolfCreek1968['Parameter Code'] = WolfCreek1968['Parameter Code'].apply(lambda x: '{:0>5}'.format(x))
WolfCreek1968.sort('Date', ascending=[False])
#WolfCreek1968['Date'].to_datetime(WolfCreek1968['Date'])
#WolfCreek1968
# Out:
#         Tag      Date Parameter Code  Values
# 31  Z004991  12/03/68          00945    68.0
# 29  Z004991  12/03/68          00403     8.3
# 28  Z004991  12/03/68          00310     1.0
# 27  Z004991  12/03/68          00300    12.0
# 26  Z004991  12/03/68          00095  1600.0
# 25  Z004991  12/03/68          00070     5.0
# 24  Z004991  12/03/68          00020    10.0
# 23  Z004991  12/03/68          00011    44.6
# 22  Z004991  12/03/68          00010     7.0
# 30  Z004991  12/03/68          00940   276.0
# 13  Z004990  11/13/68          00010    14.0
# 14  Z004990  11/13/68          00011    57.2
# 16  Z004990  11/13/68          00095  1590.0
# 17  Z004990  11/13/68          00300     9.0
# 18  Z004990  11/13/68          00310     2.5
# 19  Z004990  11/13/68          00403     8.2
# 20  Z004990  11/13/68          00940   253.0
# 21  Z004990  11/13/68          00945    79.0
# 15  Z004990  11/13/68          00070    28.0
# 7   Z004989  10/10/68          00095   576.0
# 6   Z004989  10/10/68          00070   500.0
# 9   Z004989  10/10/68          00310     4.0
# 12  Z004989  10/10/68          00945    23.0
# 10  Z004989  10/10/68          00403     7.4
# 11  Z004989  10/10/68          00940    80.0
# 8   Z004989  10/10/68          00300     8.0
# 2   Z004988  09/25/68          00310     1.0
# 1   Z004988  09/25/68          00300    11.0
# 0   Z004988  09/25/68          00095  1738.0
# 5   Z004988  09/25/68          00945    59.0
# 4   Z004988  09/25/68          00940   323.0
# 3   Z004988  09/25/68          00403     8.2

# %%
#Importing Parameter_Guide b/c it's going to be used later when merging 
Parameter_Guide = pd.read_csv(r'/Users/aolawale/Downloads/Data or Programming/TCEQ Parameter Name Guide.csv', sep='|')


Parameter_Guide
# Out:
#      Parameter Code                              Parameter Description  \
# 0             00003           SAMPLING STATION LOCATION, VERTICAL FEET
# 1             00004                                STREAM WIDTH (FEET)
# 2             00010            TEMPERATURE, WATER (DEGREES CENTIGRADE)
# 3             00011            TEMPERATURE, WATER (DEGREES FAHRENHEIT)
# 4             00019                             SAMPLE WEIGHT IN GRAMS
# 5             00020              TEMPERATURE, AIR (DEGREES CENTIGRADE)
# 6             00021              TEMPERATURE, AIR (DEGREES FAHRENHEIT)
# 7             00023                            SAMPLE WEIGHT IN POUNDS
# 8             00024                            SAMPLE LENGTH IN INCHES
# 9             00029           FIELD SPECIMEN OR SAMPLE SEQUENCE NUMBER
# 10            00039                       SAMPLE LENGTH IN MILLIMETERS
# 11            00051  RESERVOIR ACCESS NOT POSSIBLE LEVEL TOO LOW EN...
# 12            00052        RESERVOIR STAGE (FEET ABOVE MEAN SEA LEVEL)
# 13            00053                             RESERVOIR PERCENT FULL
# 14            00054                      RESERVOIR STORAGE - ACRE FEET
# 15            00055                  STREAM VELOCITY (FEET PER SECOND)
# 16            00056                        FLOW RATE (GALLONS PER DAY)
# 17            00060      FLOW, STREAM, MEAN DAILY (CUBIC FEET PER SEC)
# 18            00061   FLOW  STREAM, INSTANTANEOUS (CUBIC FEET PER SEC)
# 19            00062         ELEVATION, RESERVOIR SURFACE WATER IN FEET
# 20            00064                         DEPTH OF STREAM, MEAN (FT)
# 21            00065                               STAGE, STREAM (FEET)
# 22            00068                   DEPTH, MAXIMUM, OF SAMPLE (FEET)
# 23            00070                  TURBIDITY, (JACKSON CANDLE UNITS)
# 24            00076   TURBIDITY,HACH TURBIDIMETER (FORMAZIN TURB UNIT)
# 25            00077                 TRANSPARENCY, SECCHI DISC (INCHES)
# 26            00078                 TRANSPARENCY, SECCHI DISC (METERS)
# 27            00080                      COLOR (PLATINUM-COBALT UNITS)
# 28            00081   COLOR,APPARENT(UNFILTERED SAMPLE) PLAT-COB UNITS
# 29            00090         OXIDATION REDUCTION POTENTIAL (MILLIVOLTS)
# ...             ...                                                ...
# 5845          P5027              HEXACHLOROBENZENE IN POREWATER (UG/L)
# 5846          P5028            HEXACHLOROBUTADIENE IN POREWATER (UG/L)
# 5847          P5029      HEXACHLOROCYCLOPENTADIENE IN POREWATER (UG/L)
# 5848          P5030               HEXACHLOROETHANE IN POREWATER (UG/L)
# 5849          P5031                     ISOPHORONE IN POREWATER (UG/L)
# 5850          P5032                   NITROBENZENE IN POREWATER (UG/L)
# 5851          P5033                  2-NITROPHENOL IN POREWATER (UG/L)
# 5852          P5034                  4-NITROPHENOL IN POREWATER (UG/L)
# 5853          P5035         N-NITROSODIMETHYLAMINE IN POREWATER (UG/L)
# 5854          P5036         N-NITROSODIPHENYLAMINE IN POREWATER (UG/L)
# 5855          P5037      N-NITROSODI-N-PROPYLAMINE IN POREWATER (UG/L)
# 5856          P5038              PENTACHLOROPHENOL IN POREWATER (UG/L)
# 5857          P5039                         PHENOL IN POREWATER (UG/L)
# 5858          P5040         1,2,4-TRICHLOROBENZENE IN POREWATER (UG/L)
# 5859          P5041          2,4,6-TRICHLOROPHENOL IN POREWATER (UG/L)
# 5860          P6001                   ACENAPHTHENE IN POREWATER (UG/L)
# 5861          P6002                 ACENAPHTHYLENE IN POREWATER (UG/L)
# 5862          P6003                     ANTHRACENE IN POREWATER (UG/L)
# 5863          P6004             BENZO(A)ANTHRACENE IN POREWATER (UG/L)
# 5864          P6005           BENZO(K)FLUORANTHENE IN POREWATER (UG/L)
# 5865          P6006           BENZO(B)FLUORANTHENE IN POREWATER (UG/L)
# 5866          P6007             BENZO(GHI)PERYLENE IN POREWATER (UG/L)
# 5867          P6009                       CHRYSENE IN POREWATER (UG/L)
# 5868          P6010          DIBENZO(AH)ANTHRACENE IN POREWATER (UG/L)
# 5869          P6011                   FLUORANTHENE IN POREWATER (UG/L)
# 5870          P6012                       FLUORENE IN POREWATER (UG/L)
# 5871          P6013         INDENO(1,2,3-CD)PYRENE IN POREWATER (UG/L)
# 5872          P6014                    NAPHTHALENE IN POREWATER (UG/L)
# 5873          P6015                   PHENANTHRENE IN POREWATER (UG/L)
# 5874          P6016                         PYRENE IN POREWATER (UG/L)
#
#       Units of Measurement  Media           Method
# 0                       FT  Other  N/A Calculation
# 1                       FT  Water  N/A Calculation
# 2                    DEG C  Water  N/A Calculation
# 3                    DEG F  Water  N/A Calculation
# 4                        G  Other  N/A Calculation
# 5                    DEG C    Air  N/A Calculation
# 6                    DEG F    Air  N/A Calculation
# 7                       LB  Other  N/A Calculation
# 8                       IN  Other  N/A Calculation
# 9                       NU  Other  N/A Calculation
# 10                      MM  Other  N/A Calculation
# 11                      NS  Other  N/A Calculation
# 12            FT ABOVE MSL  Water  N/A Calculation
# 13    % RESERVOIR CAPACITY  Water  N/A Calculation
# 14                   AC-FT  Other  N/A Calculation
# 15                  FT/SEC  Water  N/A Calculation
# 16                 GAL/DAY  Water  N/A Calculation
# 17                     CFS  Water  N/A Calculation
# 18                     CFS  Water  N/A Calculation
# 19                      FT  Water  N/A Calculation
# 20                      FT  Water  N/A Calculation
# 21                      FT  Water  N/A Calculation
# 22                      FT  Water  N/A Calculation
# 23                     JTU  Water  N/A Calculation
# 24                     FTU  Water  N/A Calculation
# 25                      IN  Water  N/A Calculation
# 26                       M  Water  N/A Calculation
# 27                     PCU  Water  N/A Calculation
# 28                     PCU  Water  N/A Calculation
# 29                      mV  Water  N/A Calculation
# ...                    ...    ...              ...
# 5845                  UG/L  Other  N/A Calculation
# 5846                  UG/L  Other  N/A Calculation
# 5847                  UG/L  Other  N/A Calculation
# 5848                  UG/L  Other  N/A Calculation
# 5849                  UG/L  Other  N/A Calculation
# 5850                  UG/L  Other  N/A Calculation
# 5851                  UG/L  Other  N/A Calculation
# 5852                  UG/L  Other  N/A Calculation
# 5853                  UG/L  Other  N/A Calculation
# 5854                  UG/L  Other  N/A Calculation
# 5855                  UG/L  Other  N/A Calculation
# 5856                  UG/L  Other  N/A Calculation
# 5857                  UG/L  Other  N/A Calculation
# 5858                  UG/L  Other  N/A Calculation
# 5859                  UG/L  Other  N/A Calculation
# 5860                  UG/L  Other  N/A Calculation
# 5861                  UG/L  Other  N/A Calculation
# 5862                  UG/L  Other  N/A Calculation
# 5863                  UG/L  Other  N/A Calculation
# 5864                  UG/L  Other  N/A Calculation
# 5865                  UG/L  Other  N/A Calculation
# 5866                  UG/L  Other  N/A Calculation
# 5867                  UG/L  Other  N/A Calculation
# 5868                  UG/L  Other  N/A Calculation
# 5869                  UG/L  Other  N/A Calculation
# 5870                  UG/L  Other  N/A Calculation
# 5871                  UG/L  Other  N/A Calculation
# 5872                  UG/L  Other  N/A Calculation
# 5873                  UG/L  Other  N/A Calculation
# 5874                  UG/L  Other  N/A Calculation
#
# [5875 rows x 5 columns]

# %%
#glob.glob(*.csv) finds all files saved as csv files in the folder where this notebook is saved and prints them out
mergeFiles = glob.glob('*.csv')
mergeFiles
# Out:
# ['FlorenceN.csv',
#  'ISWS_Water_Quality.csv',
#  'LeadLevels.csv',
#  'TCEQ Parameter Name Guide.csv',
#  'Wolf Creek Water Data (1968).csv',
#  'WolfCreek1968.csv',
#  'WolfCreek1968_Merged.csv']

# %%
#Remember: mergeFiles is just all the csv files in the folder where this is saved
def mergeFile(WolfCreek1968, mergeFiles):
    #for each csv file in mergeFiles
    for file in mergeFiles:
        #read each as a csv file, and read only the first(0), second(1), third(2), and fifth(4) columns
        file = pd.read_csv(file, sep="|", usecols=[0,1,2,4], header=None)
        #rename the 1st column to Tag, 2nd column to Date, 3rd to Parameter Code, and 4th to Values
        file.columns=['Tag','Date','Parameter Code','Values']
        #add leading zeroes to the Parameter Code column since they'll most likely be double digits
        file['Parameter Code'] = file['Parameter Code'].apply(lambda x: '{:0>5}'.format(x))
        #concat basically means 'join together', so join WolfCreek1968 and each csv file vertically (axis = 0)
        fileConcat = pd.concat([WolfCreek1968, file], axis=0)
        #now WolfCreek1968 = WolfCreek1968 + first csv file in the first loop
        #in the next loop, it would be WolfCreek1968 + first csv file = WolfCreek1968 + 1st csv file + 2nd csv file in mergeFiles
        WolfCreek1968 = fileConcat
    #show me WolfCreek1968 + 1st csv + 2nd csv + 3rd csv +..... last csv
    return fileConcat

# %%
AlmostMasterFile = mergeFile(WolfCreek1968, mergeFiles)
#converting the date column to datetime format or there'll be trouble w/ sorting the final dataframe
AlmostMasterFile['Date']=pd.to_datetime(AlmostMasterFile['Date'])
#AlmostMasterFile['Date']
AlmostMasterFile.sort('Date', ascending=[True])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-6-5b5a85c2e0fd> in <module>()
# ----> 1 AlmostMasterFile = mergeFile(WolfCreek1968, mergeFiles)
#       2 #converting the date column to datetime format or there'll be trouble w/ sorting the final dataframe
#       3 AlmostMasterFile['Date']=pd.to_datetime(AlmostMasterFile['Date'])
#       4 #AlmostMasterFile['Date']
#       5 AlmostMasterFile.sort('Date', ascending=[True])
#
# <ipython-input-5-31db1a6b5811> in mergeFile(WolfCreek1968, mergeFiles)
#       4     for file in mergeFiles:
#       5         #read each as a csv file, and read only the first(0), second(1), third(2), and fifth(4) columns
# ----> 6         file = pd.read_csv(file, sep="|", usecols=[0,1,2,4], header=None)
#       7         #rename the 1st column to Tag, 2nd column to Date, 3rd to Parameter Code, and 4th to Values
#       8         file.columns=['Tag','Date','Parameter Code','Values']
#
# /usr/local/lib/python3.4/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, dialect, compression, doublequote, escapechar, quotechar, quoting, skipinitialspace, lineterminator, header, index_col, names, prefix, skiprows, skipfooter, skip_footer, na_values, na_fvalues, true_values, false_values, delimiter, converters, dtype, usecols, engine, delim_whitespace, as_recarray, na_filter, compact_ints, use_unsigned, low_memory, buffer_lines, warn_bad_lines, error_bad_lines, keep_default_na, thousands, comment, decimal, parse_dates, keep_date_col, dayfirst, date_parser, memory_map, float_precision, nrows, iterator, chunksize, verbose, encoding, squeeze, mangle_dupe_cols, tupleize_cols, infer_datetime_format, skip_blank_lines)
#     472                     skip_blank_lines=skip_blank_lines)
#     473
# --> 474         return _read(filepath_or_buffer, kwds)
#     475
#     476     parser_f.__name__ = name
#
# /usr/local/lib/python3.4/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     248
#     249     # Create the parser.
# --> 250     parser = TextFileReader(filepath_or_buffer, **kwds)
#     251
#     252     if (nrows is not None) and (chunksize is not None):
#
# /usr/local/lib/python3.4/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     564             self.options['has_index_names'] = kwds['has_index_names']
#     565
# --> 566         self._make_engine(self.engine)
#     567
#     568     def _get_options_with_defaults(self, engine):
#
# /usr/local/lib/python3.4/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#     703     def _make_engine(self, engine='c'):
#     704         if engine == 'c':
# --> 705             self._engine = CParserWrapper(self.f, **self.options)
#     706         else:
#     707             if engine == 'python':
#
# /usr/local/lib/python3.4/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1111                           if i in col_indices]
#    1112             if len(self.names) < len(self.usecols):
# -> 1113                 raise ValueError("Usecols do not match names.")
#    1114
#    1115         self._set_noconvert_columns()
#
# ValueError: Usecols do not match names.

# %%
#Merging the combined dataframes w/ the Parameter Guide
#MasterFile06 = AlmostMasterFile.sort(['Parameter Code','Date'], ascending=[True, True])
#MasterFile06 = MasterFile06.merge(Parameter_Guide, on ='Parameter Code')
#MasterFile06.to_csv("MasterFile06.csv")
#MasterFile06[60:160]
#MasterFile06.where(MasterFile06['Parameter Code'] == '00095')
MasterFile06 = AlmostMasterFile.merge(Parameter_Guide, on='Parameter Code')
MasterFile06 = MasterFile06.sort(['Parameter Code','Date'], ascending=[True, True])
#Sorted by parameter code first and then by date
MasterFile06

# %%
#Looking for rows where the parameter description includes water data
WaterClarityData = np.where(MasterFile06['Parameter Description'] == 'WATER CLARITY, 1=EXCELLENT 2=GOOD 3=FAIR 4=POOR')
WaterClarityData

# %%
WaterClarityGraph = MasterFile06[4019:4044]
WaterClarityGraph

x_axis = (WaterClarityGraph['Date'])
x_axis



y_axis = (WaterClarityGraph['Values'])
y_axis





#ax = WaterClarityGraph.plot(x='Date', y= 'Values', kind='bar', color='red')
#plt.xlabel('Date')
#plt.ylabel('Water Clarity')
#plt.title('Wolf Creek Water Clarity (1968-2006)')

#mdates.DateFormatter('%d-%m-%Y')
#plt.show()


#plt.scatter(x_axis, y_axis)
#mdates.DateFormatter('%d-%m-%Y')
#plt.xlabel('Date')
#plt.show()

# %%
WaterClarityGraph = MasterFile06[4019:4044]
WaterClarityGraph

# %%
#MasterFile06.sort(['Date'], ascending = [True] )
#MasterFile06.reindex(columns=['Date'])
#MasterFile06 = MasterFile06.groupby(['Parameter Code'])
#MasterFile06['Date']

#Finding the parameter codes with the most entries
MasterFile06['Parameter Code'].value_counts()

# %%
DissolvedOxygen = np.where(MasterFile06['Parameter Code'] == '00300')
DissolvedOxygen

DOdf = MasterFile06[1204:1536]
DOdf

DOdf.plot(x='Date', y='Values', kind='line', color='blue')
plt.xlabel('Date')
plt.ylabel('DO levels (MG/L)')
plt.title('Wolf Creek Dissolved Oxygen Levels (MG/L) 1968-2006')
plt.axhline(y=3, xmin=0, xmax=3, linewidth=1, color='red', label='Dangerously low levels')
plt.legend()
plt.show()

# %%
'''
TempC = np.where(MasterFile06['Parameter Code'] == '00010')
TempC

TempCdf = MasterFile06[0:309]
TempCdf

TempCdf.plot(x='Date', y='Values', kind='line', color='blue')
plt.xlabel('Date')
mdates.DateFormatter('%d-%m-%Y')
plt.ylabel('Temperature (Celsius)')
plt.title('Wolf Creek Water Temperature (Celsius) 1968-2006')
#ax.set_xticklabels(mdates.DateFormatter('%d-%m-%Y'))
plt.show()
'''

# %%
'''
SpecificConductance = np.where(MasterFile06['Parameter Code'] == '00094')
SpecificConductance


SCdf = MasterFile06[820:1106]
SCdf

SCdf.plot(x='Date', y='Values', kind='line', color='red')
plt.xlabel('Date')
plt.ylabel('Wolf Creek Specific Conductance (uS/cm) 1972-2006')
plt.show()
'''
# Out:
# "\nSpecificConductance = np.where(MasterFile06['Parameter Code'] == '00094')\nSpecificConductance\n\n\nSCdf = MasterFile06[820:1106]\nSCdf\n\nSCdf.plot(x='Date', y='Values', kind='line', color='red')\nplt.xlabel('Date')\nplt.ylabel('Wolf Creek Specific Conductance (uS/cm) 1972-2006')\nplt.show()\n"

# %%
def dummyGraphAny(y):
    yName = np.where(MasterFile06['Parameter Code'] == y)[0]
    yNamedf = MasterFile06[(yName[0]):(yName[-1])]
    print (yNamedf['Date'][:1])
    print (yNamedf['Date'][-1:])
    print (yNamedf['Parameter Description'][:1])
    yNamedf.plot(x='Date', y='Values', kind='line', color='red')
    plt.xlabel('Date')
    yax = input('Enter y-axis label: ')
    plt.ylabel(yax)
    title= input('Enter title: ')
    plt.title(title)
    plt.show()
  
    
    
        
    #slice = yName[0:18]
    #return slice
    #yNameArray = MasterFile06[(yName[0]):(yName[-1])]
    #return yNameArray
    
    #Trying to figure out how to find the date and parameter code I'm graphing for y-axis label and title 
     #print (yNamedf[:1])
    #print (yNamedf[-1:])
    
    #print (yNamedf['Date'][:1], yNamedf['Parameter Description'][:1])

# %%
#y= '00011'
#dummyGraphAny(y)

#y= '00011'
#dummyGraphAny(y)

y='00094'
dummyGraphAny('00010')

# %%
#MasterFile06.to_csv('MasterFile06.csv')
