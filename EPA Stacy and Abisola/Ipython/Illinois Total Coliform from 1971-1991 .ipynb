# %%
import matplotlib.pyplot as pyplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv('Desktop\RDCEP\EPA CSV FILES\IllinoisTotalColiform.csv')
df.columns = ['ProjectID', 'Prj_Name', 'Prj_Description', 'MLocID', 'MLoc_Type', 'MLoc_Description', 'River_Name', 'RiverMile', 'NavigationPool', 'NavMile', 'Latitude', 'Longitude', 'HRDAT_Name', 'HCMETH_Name', 'HUC_8', 'HUC_12', 'ActivityID', 'Date', 'TimeZone', 'Valid_Time', 'Activity_Type', 'Act_RelDepth', 'Act_Depth_Height', 'Act_Depth_Height_Unit', 'SCEQP_Name', 'ResultID', 'Result_Flag', 'Result_Qualifier', 'ResultValue(colony forming units per 100mL)', 'Result_Unit', 'Result_Lab_Name', 'Result_Lab_Comment', 'CharacteristicID', 'Chr_Name', 'ANLMTH_ID', 'ANLMTH_Name', 'ANLMTH_Desc', 'ANLMTH_Ref']
df
# Out:
#       ProjectID                                  Prj_Name  \
# 0             3  ISWS Illinois River at Peoria Monitoring
# 1             3  ISWS Illinois River at Peoria Monitoring
# 2             3  ISWS Illinois River at Peoria Monitoring
# 3             3  ISWS Illinois River at Peoria Monitoring
# 4             3  ISWS Illinois River at Peoria Monitoring
# 5             3  ISWS Illinois River at Peoria Monitoring
# 6             3  ISWS Illinois River at Peoria Monitoring
# 7             3  ISWS Illinois River at Peoria Monitoring
# 8             7        ISWS Upper Illinois Waterway Study
# 9             7        ISWS Upper Illinois Waterway Study
# 10            7        ISWS Upper Illinois Waterway Study
# 11            7        ISWS Upper Illinois Waterway Study
# 12            7        ISWS Upper Illinois Waterway Study
# 13            7        ISWS Upper Illinois Waterway Study
# 14            7        ISWS Upper Illinois Waterway Study
# ...

# %%
df['ResultValue(colony forming units per 100mL)']
# Out:
# 0        800
# 1      23000
# 2       1700
# 3       1200
# 4        190
# 5       2400
# 6       5200
# 7       2200
# 8     240000
# 9     250000
# 10    280000
# 11    240000
# 12     14000
# 13      7100
# 14     38000
# ...
# 1147    1100
# 1148    3000
# 1149     400
# 1150     530
# 1151    1400
# 1152     440
# 1153     320
# 1154     750
# 1155    1200
# 1156     500
# 1157     420
# 1158    2600
# 1159     480
# 1160    1400
# 1161    5300
# Name: ResultValue(colony forming units per 100mL), Length: 1162, dtype: int64

# %%
df[:1161]
# Out:
#       ProjectID                                  Prj_Name  \
# 0             3  ISWS Illinois River at Peoria Monitoring
# 1             3  ISWS Illinois River at Peoria Monitoring
# 2             3  ISWS Illinois River at Peoria Monitoring
# 3             3  ISWS Illinois River at Peoria Monitoring
# 4             3  ISWS Illinois River at Peoria Monitoring
# 5             3  ISWS Illinois River at Peoria Monitoring
# 6             3  ISWS Illinois River at Peoria Monitoring
# 7             3  ISWS Illinois River at Peoria Monitoring
# 8             7        ISWS Upper Illinois Waterway Study
# 9             7        ISWS Upper Illinois Waterway Study
# 10            7        ISWS Upper Illinois Waterway Study
# 11            7        ISWS Upper Illinois Waterway Study
# 12            7        ISWS Upper Illinois Waterway Study
# 13            7        ISWS Upper Illinois Waterway Study
# 14            7        ISWS Upper Illinois Waterway Study
# ...

# %%
df['ResultValue(colony forming units per 100mL)'][:1161]
# Out:
# 0        800
# 1      23000
# 2       1700
# 3       1200
# 4        190
# 5       2400
# 6       5200
# 7       2200
# 8     240000
# 9     250000
# 10    280000
# 11    240000
# 12     14000
# 13      7100
# 14     38000
# ...
# 1146     700
# 1147    1100
# 1148    3000
# 1149     400
# 1150     530
# 1151    1400
# 1152     440
# 1153     320
# 1154     750
# 1155    1200
# 1156     500
# 1157     420
# 1158    2600
# 1159     480
# 1160    1400
# Name: ResultValue(colony forming units per 100mL), Length: 1161, dtype: int64

# %%
df['ResultValue(colony forming units per 100mL)'].plot()

# %%
df.plot(x='Date', y='ResultValue(colony forming units per 100mL)')

# %%
plt.title ('Yearly Total Coliform from 1971-1991 in Peoria, IL')
plt.xlabel('Date')
plt.ylabel('ResultValue(colony forming unit per 100mL)')

# %%
plt.axhline(y=0, xmin=0, xmax=0, linewidth=5, color = 'r', label='Maximum Acceptable Concentration for Drinking Water=none detectable per 100ml')

# %%
plt.legend()
plt.show()
