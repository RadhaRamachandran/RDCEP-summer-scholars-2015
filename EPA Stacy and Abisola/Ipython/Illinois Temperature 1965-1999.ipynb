# %%
import matplotlib.pyplot as pyplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv('Desktop\RDCEP\EPA CSV FILES\IllinoisTemperature.csv')
df.columns = ['ProjectID', 'Prj_Name', 'Prj_Description', 'MLocID', 'MLoc_Type', 'MLoc_Description', 'River_Name', 'RiverMile', 'NavigationPool', 'NavMile', 'Latitude', 'Longitude', 'HRDAT_Name', 'HCMETH_Name', 'HUC_8', 'HUC_12', 'ActivityID', 'Date', 'TimeZone', 'Valid_Time', 'Activity_Time', 'Act_RelDepth', 'Act_Depth_Height', 'Act_Depth_Height_Unit', 'SCEQP_Name', 'ResultID', 'Result_Flag', 'Result_Qualifier', 'ResultValue(Celsius)', 'Result_Unit', 'Result_Lab_Name', 'Result_Lab_Commenet', 'CharacteristicID', 'Chr_Name', 'ANLMTH_ID', 'ANLMTH_Name', 'ANLMTH_Desc', 'ANLMTH_Ref']
df
# Out:
# C:\Users\Dell\Anaconda3\lib\site-packages\pandas\io\parsers.py:1159: DtypeWarning: Columns (23,24,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)
#         ProjectID                                  Prj_Name  \
# 0               3  ISWS Illinois River at Peoria Monitoring
# 1               3  ISWS Illinois River at Peoria Monitoring
# 2               3  ISWS Illinois River at Peoria Monitoring
# 3               3  ISWS Illinois River at Peoria Monitoring
# 4               3  ISWS Illinois River at Peoria Monitoring
# 5               3  ISWS Illinois River at Peoria Monitoring
# 6               3  ISWS Illinois River at Peoria Monitoring
# 7               3  ISWS Illinois River at Peoria Monitoring
# 8               3  ISWS Illinois River at Peoria Monitoring
# 9               3  ISWS Illinois River at Peoria Monitoring
# 10              3  ISWS Illinois River at Peoria Monitoring
# ...

# %%
df['ResultValue(Celsius)']
# Out:
# 0     1.2
# 1     3.5
# 2     0.2
# 3     0.0
# 4     0.0
# 5     0.5
# 6     0.2
# 7     0.0
# 8     0.1
# 9     0.1
# 10    0.2
# 11    0.2
# 12    0.7
# 13    2.0
# 14    0.8
# ...
# 107779    13.0
# 107780    18.5
# 107781    23.5
# 107782    28.1
# 107783    27.7
# 107784    29.4
# 107785    27.7
# 107786    27.8
# 107787    24.6
# 107788    16.0
# 107789    12.0
# 107790     0.5
# 107791     0.0
# 107792     2.5
# 107793     4.8
# Name: ResultValue(Celsius), Length: 107794, dtype: float64

# %%
df[:107793]
# Out:
#         ProjectID                                  Prj_Name  \
# 0               3  ISWS Illinois River at Peoria Monitoring
# 1               3  ISWS Illinois River at Peoria Monitoring
# 2               3  ISWS Illinois River at Peoria Monitoring
# 3               3  ISWS Illinois River at Peoria Monitoring
# 4               3  ISWS Illinois River at Peoria Monitoring
# 5               3  ISWS Illinois River at Peoria Monitoring
# 6               3  ISWS Illinois River at Peoria Monitoring
# 7               3  ISWS Illinois River at Peoria Monitoring
# 8               3  ISWS Illinois River at Peoria Monitoring
# 9               3  ISWS Illinois River at Peoria Monitoring
# 10              3  ISWS Illinois River at Peoria Monitoring
# 11              3  ISWS Illinois River at Peoria Monitoring
# 12              3  ISWS Illinois River at Peoria Monitoring
# 13              3  ISWS Illinois River at Peoria Monitoring
# 14              3  ISWS Illinois River at Peoria Monitoring
# ...

# %%
df['ResultValue(Celsius)'][:107793]
# Out:
# 0     1.2
# 1     3.5
# 2     0.2
# 3     0.0
# 4     0.0
# 5     0.5
# 6     0.2
# 7     0.0
# 8     0.1
# 9     0.1
# 10    0.2
# 11    0.2
# 12    0.7
# 13    2.0
# 14    0.8
# ...
# 107778    13.0
# 107779    13.0
# 107780    18.5
# 107781    23.5
# 107782    28.1
# 107783    27.7
# 107784    29.4
# 107785    27.7
# 107786    27.8
# 107787    24.6
# 107788    16.0
# 107789    12.0
# 107790     0.5
# 107791     0.0
# 107792     2.5
# Name: ResultValue(Celsius), Length: 107793, dtype: float64

# %%
df['ResultValue(Celsius)'].plot()

# %%
df.plot(x='Date', y='ResultValue(Celsius)')

# %%
plt.title('Yearly Water Temperature from 1965-1999 in Peoria, IL')
plt.xlabel('Date')
plt.ylabel('ResultValue(Celsius)')

# %%
plt.axhline(y=29, xmin=0, xmax=29, linewidth=5, color = 'r',label='Maximum Daily Average Temperature for Warm Water=29C or 84F')
plt.axhline(y=23, xmin=0, xmax=23, linewidth=5, color = 'green', label='Maximum Daily Average Temperature for Seasonal Cold=23C or 73F')
plt.axhline(y=19, xmin=0, xmax=19, linewidth=5, color = 'orange', label='Maximum Daily Average Temperature for Cold Water=19C or 66F')

# %%
plt.legend()
plt.show()
