# %%
import matplotlib.pyplot as pyplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv('Desktop\RDCEP\EPA CSV FILES\IllinoisDissolvedNitrate.csv')
df.columns = ['ProjectID', 'Prj_Name', 'Prj_Description', 'MLocID', 'MLoc_Type', 'MLoc_Description', 'River_Name', 'RiverMile', 'NavigationPool', 'NavMile', 'Latitude', 'Longitude', 'HRDAT_Name', 'HCMETH_Name', 'HUC_8', 'HUC_12', 'ActivityID', 'Date', 'TimeZone', 'Valid_Time', 'Activity_Type', 'Act_RelDepth', 'Act_Depth_Height', 'Act_Depth_Height_Unit', 'SCEQP_Name', 'ResultID', 'Result_Flag', 'Result_Qualifier', 'ResultValue(mg/L)', 'Result_Unit', 'Result_Lab_Name', 'Result_Lab_Comment', 'CharacteristicID', 'Chr_Name', 'ANLMTH_ID', 'ANLMTH_Name', 'ANLMTH_Desc', 'ANLMTH_Ref']
df
# Out:
#       ProjectID                                  Prj_Name  \
# 0             7        ISWS Upper Illinois Waterway Study
# 1             7        ISWS Upper Illinois Waterway Study
# 2             7        ISWS Upper Illinois Waterway Study
# 3             7        ISWS Upper Illinois Waterway Study
# 4             7        ISWS Upper Illinois Waterway Study
# 5             7        ISWS Upper Illinois Waterway Study
# 6             7        ISWS Upper Illinois Waterway Study
# 7             7        ISWS Upper Illinois Waterway Study
# 8             7        ISWS Upper Illinois Waterway Study
# 9             7        ISWS Upper Illinois Waterway Study
# 10            7        ISWS Upper Illinois Waterway Study
# 11            7        ISWS Upper Illinois Waterway Study
# 12            7        ISWS Upper Illinois Waterway Study
# 13            7        ISWS Upper Illinois Waterway Study
# 14            7        ISWS Upper Illinois Waterway Study
# ...

# %%
df['ResultValue(mg/L)']
# Out:
# 0     0.61
# 1     0.22
# 2     0.30
# 3     0.28
# 4     0.40
# 5     0.61
# 6     0.65
# 7     0.24
# 8     0.93
# 9     0.28
# 10    0.45
# 11    0.36
# 12    0.20
# 13    0.38
# 14    0.89
# ...
# 1188    0.04
# 1189    0.04
# 1190    0.04
# 1191    0.07
# 1192    0.06
# 1193    0.05
# 1194    0.05
# 1195    0.07
# 1196    0.06
# 1197    0.05
# 1198    0.04
# 1199    0.13
# 1200    0.05
# 1201    0.08
# 1202    0.09
# Name: ResultValue(mg/L), Length: 1203, dtype: float64

# %%
df[:1202]
# Out:
#       ProjectID                                  Prj_Name  \
# 0             7        ISWS Upper Illinois Waterway Study
# 1             7        ISWS Upper Illinois Waterway Study
# 2             7        ISWS Upper Illinois Waterway Study
# 3             7        ISWS Upper Illinois Waterway Study
# 4             7        ISWS Upper Illinois Waterway Study
# 5             7        ISWS Upper Illinois Waterway Study
# 6             7        ISWS Upper Illinois Waterway Study
# 7             7        ISWS Upper Illinois Waterway Study
# 8             7        ISWS Upper Illinois Waterway Study
# 9             7        ISWS Upper Illinois Waterway Study
# 10            7        ISWS Upper Illinois Waterway Study
# 11            7        ISWS Upper Illinois Waterway Study
# 12            7        ISWS Upper Illinois Waterway Study
# 13            7        ISWS Upper Illinois Waterway Study
# 14            7        ISWS Upper Illinois Waterway Study
# ...

# %%
df['ResultValue(mg/L)'][:1202]
# Out:
# 0     0.61
# 1     0.22
# 2     0.30
# 3     0.28
# 4     0.40
# 5     0.61
# 6     0.65
# 7     0.24
# 8     0.93
# 9     0.28
# 10    0.45
# 11    0.36
# 12    0.20
# 13    0.38
# 14    0.89
# ...
# 1187    1.05
# 1188    0.04
# 1189    0.04
# 1190    0.04
# 1191    0.07
# 1192    0.06
# 1193    0.05
# 1194    0.05
# 1195    0.07
# 1196    0.06
# 1197    0.05
# 1198    0.04
# 1199    0.13
# 1200    0.05
# 1201    0.08
# Name: ResultValue(mg/L), Length: 1202, dtype: float64

# %%
df['ResultValue(mg/L)'].plot()

# %%
df.plot(x='Date', y='ResultValue(mg/L)')

# %%
plt.title('Yearly Nitrogen, Dissolved Nitrite from 1969-1994 in Peoria, IL')
plt.xlabel('Date')
plt.ylabel('ResultValue(mg/L)')

# %%
plt.axhline(y=10, xmin=0, xmax=10, linewidth=5, color = 'r',label='Maximum Contaminant Level of Nitrogen,Nitrite')
plt.axhline(y=1, xmin=0, xmax=10, linewidth=1, color = 'g',label='Maximum Contaminant Level of Nitrogen,Nitrite for regulated public water systems')

# %%
plt.legend()
plt.show()
