# %%
import matplotlib.pyplot as pyplot
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import csv

# %%
df = pd.read_csv('Desktop\RDCEP\EPA CSV FILES\IllinoisDissolvedOxygen.csv')
df.columns = ['ProjectID', 'Prj_Name', 'Prj_Description', 'MLocID', 'MLoc_Type', 'MLoc_Description', 'River_Name', 'RiverMile', 'NavigationPool', 'NavMile', 'Latitude', 'Longitude', 'HRDAT_Name', 'HCMETH_Name', 'HUC_8', 'HUC_12', 'ActivityID', 'Date', 'TimeZone', 'Valid_Time', 'Activity_Type', 'Act_RelDepth', 'Act_Depth_Height', 'Act_Depth_Height_Unit', 'SCEQP_Name', 'ResultID', 'Result_Flag', 'Result_Qualifier', 'ResultValue(mg/L)', 'Result_Unit', 'Result_Lab_Name', 'Result_Lab_Comment', 'CharacteristicID', 'Chr_Name', 'ANLMTH_ID', 'ANLMTH_Name', 'ANLMTH_Desc', 'ANLMTH_Ref']
df
# Out:
#         ProjectID                                  Prj_Name  \
# 0               3  ISWS Illinois River at Peoria Monitoring
# 1               3  ISWS Illinois River at Peoria Monitoring
# 2               3  ISWS Illinois River at Peoria Monitoring
# 3               3  ISWS Illinois River at Peoria Monitoring
# 4               3  ISWS Illinois River at Peoria Monitoring
# 5               3  ISWS Illinois River at Peoria Monitoring
# 6               3  ISWS Illinois River at Peoria Monitoring
# 7               3  ISWS Illinois River at Peoria Monitoring
# 8               3  ISWS Illinois River at Peoria Monitoring
# 9               3  ISWS Illinois River at Peoria Monitoring
# 10              3  ISWS Illinois River at Peoria Monitoring
# 11              3  ISWS Illinois River at Peoria Monitoring
# 12              3  ISWS Illinois River at Peoria Monitoring
# 13              3  ISWS Illinois River at Peoria Monitoring
# 14              3  ISWS Illinois River at Peoria Monitoring
# 15              3  ISWS Illinois River at Peoria Monitoring
# 16              3  ISWS Illinois River at Peoria Monitoring
# 17              3  ISWS Illinois River at Peoria Monitoring
# 18              3  ISWS Illinois River at Peoria Monitoring
# 19              3  ISWS Illinois River at Peoria Monitoring
# 20              3  ISWS Illinois River at Peoria Monitoring
# 21              3  ISWS Illinois River at Peoria Monitoring
# 22              3  ISWS Illinois River at Peoria Monitoring
# 23              3  ISWS Illinois River at Peoria Monitoring
# 24              3  ISWS Illinois River at Peoria Monitoring
# 25              3  ISWS Illinois River at Peoria Monitoring
# 26              3  ISWS Illinois River at Peoria Monitoring
# 27              3  ISWS Illinois River at Peoria Monitoring
# 28              3  ISWS Illinois River at Peoria Monitoring
# 29              3  ISWS Illinois River at Peoria Monitoring
# ...           ...                                       ...
# 100611          3  ISWS Illinois River at Peoria Monitoring
# 100612          3  ISWS Illinois River at Peoria Monitoring
# 100613          3  ISWS Illinois River at Peoria Monitoring
# 100614          3  ISWS Illinois River at Peoria Monitoring
# 100615          3  ISWS Illinois River at Peoria Monitoring
# 100616          3  ISWS Illinois River at Peoria Monitoring
# 100617          3  ISWS Illinois River at Peoria Monitoring
# 100618          3  ISWS Illinois River at Peoria Monitoring
# 100619          3  ISWS Illinois River at Peoria Monitoring
# 100620          3  ISWS Illinois River at Peoria Monitoring
# 100621          3  ISWS Illinois River at Peoria Monitoring
# 100622          3  ISWS Illinois River at Peoria Monitoring
# 100623          3  ISWS Illinois River at Peoria Monitoring
# 100624          3  ISWS Illinois River at Peoria Monitoring
# 100625          3  ISWS Illinois River at Peoria Monitoring
# 100626          3  ISWS Illinois River at Peoria Monitoring
# 100627          3  ISWS Illinois River at Peoria Monitoring
# 100628          3  ISWS Illinois River at Peoria Monitoring
# 100629          3  ISWS Illinois River at Peoria Monitoring
# 100630          3  ISWS Illinois River at Peoria Monitoring
# 100631          3  ISWS Illinois River at Peoria Monitoring
# 100632          3  ISWS Illinois River at Peoria Monitoring
# 100633          3  ISWS Illinois River at Peoria Monitoring
# 100634          3  ISWS Illinois River at Peoria Monitoring
# 100635          3  ISWS Illinois River at Peoria Monitoring
# 100636          3  ISWS Illinois River at Peoria Monitoring
# 100637          3  ISWS Illinois River at Peoria Monitoring
# 100638          3  ISWS Illinois River at Peoria Monitoring
# 100639          3  ISWS Illinois River at Peoria Monitoring
# 100640          3  ISWS Illinois River at Peoria Monitoring
#
#                                           Prj_Description  MLocID  \
# 0       A long-term monitoring program collecting wate...  03-001
# 1       A long-term monitoring program collecting wate...  03-001
# 2       A long-term monitoring program collecting wate...  03-001
# 3       A long-term monitoring program collecting wate...  03-001
# 4       A long-term monitoring program collecting wate...  03-001
# 5       A long-term monitoring program collecting wate...  03-001
# 6       A long-term monitoring program collecting wate...  03-001
# 7       A long-term monitoring program collecting wate...  03-001
# 8       A long-term monitoring program collecting wate...  03-001
# 9       A long-term monitoring program collecting wate...  03-001
# 10      A long-term monitoring program collecting wate...  03-001
# 11      A long-term monitoring program collecting wate...  03-001
# 12      A long-term monitoring program collecting wate...  03-001
# 13      A long-term monitoring program collecting wate...  03-001
# 14      A long-term monitoring program collecting wate...  03-001
# 15      A long-term monitoring program collecting wate...  03-001
# 16      A long-term monitoring program collecting wate...  03-001
# 17      A long-term monitoring program collecting wate...  03-001
# 18      A long-term monitoring program collecting wate...  03-001
# 19      A long-term monitoring program collecting wate...  03-001
# 20      A long-term monitoring program collecting wate...  03-001
# 21      A long-term monitoring program collecting wate...  03-001
# 22      A long-term monitoring program collecting wate...  03-001
# 23      A long-term monitoring program collecting wate...  03-001
# 24      A long-term monitoring program collecting wate...  03-001
# 25      A long-term monitoring program collecting wate...  03-001
# 26      A long-term monitoring program collecting wate...  03-001
# 27      A long-term monitoring program collecting wate...  03-001
# 28      A long-term monitoring program collecting wate...  03-001
# 29      A long-term monitoring program collecting wate...  03-001
# ...                                                   ...     ...
# 100611  A long-term monitoring program collecting wate...  03-001
# 100612  A long-term monitoring program collecting wate...  03-001
# 100613  A long-term monitoring program collecting wate...  03-001
# 100614  A long-term monitoring program collecting wate...  03-001
# 100615  A long-term monitoring program collecting wate...  03-001
# 100616  A long-term monitoring program collecting wate...  03-001
# 100617  A long-term monitoring program collecting wate...  03-001
# 100618  A long-term monitoring program collecting wate...  03-001
# 100619  A long-term monitoring program collecting wate...  03-001
# 100620  A long-term monitoring program collecting wate...  03-001
# 100621  A long-term monitoring program collecting wate...  03-001
# 100622  A long-term monitoring program collecting wate...  03-001
# 100623  A long-term monitoring program collecting wate...  03-001
# 100624  A long-term monitoring program collecting wate...  03-001
# 100625  A long-term monitoring program collecting wate...  03-001
# 100626  A long-term monitoring program collecting wate...  03-001
# 100627  A long-term monitoring program collecting wate...  03-001
# 100628  A long-term monitoring program collecting wate...  03-001
# 100629  A long-term monitoring program collecting wate...  03-001
# 100630  A long-term monitoring program collecting wate...  03-001
# 100631  A long-term monitoring program collecting wate...  03-001
# 100632  A long-term monitoring program collecting wate...  03-001
# 100633  A long-term monitoring program collecting wate...  03-001
# 100634  A long-term monitoring program collecting wate...  03-001
# 100635  A long-term monitoring program collecting wate...  03-001
# 100636  A long-term monitoring program collecting wate...  03-001
# 100637  A long-term monitoring program collecting wate...  03-001
# 100638  A long-term monitoring program collecting wate...  03-001
# 100639  A long-term monitoring program collecting wate...  03-001
# 100640  A long-term monitoring program collecting wate...  03-001
#
#            MLoc_Type                                   MLoc_Description  \
# 0       River/Stream  Right descending bank upstream of Cedar St. br...
# 1       River/Stream  Right descending bank upstream of Cedar St. br...
# 2       River/Stream  Right descending bank upstream of Cedar St. br...
# 3       River/Stream  Right descending bank upstream of Cedar St. br...
# 4       River/Stream  Right descending bank upstream of Cedar St. br...
# 5       River/Stream  Right descending bank upstream of Cedar St. br...
# 6       River/Stream  Right descending bank upstream of Cedar St. br...
# 7       River/Stream  Right descending bank upstream of Cedar St. br...
# 8       River/Stream  Right descending bank upstream of Cedar St. br...
# 9       River/Stream  Right descending bank upstream of Cedar St. br...
# 10      River/Stream  Right descending bank upstream of Cedar St. br...
# 11      River/Stream  Right descending bank upstream of Cedar St. br...
# 12      River/Stream  Right descending bank upstream of Cedar St. br...
# 13      River/Stream  Right descending bank upstream of Cedar St. br...
# 14      River/Stream  Right descending bank upstream of Cedar St. br...
# 15      River/Stream  Right descending bank upstream of Cedar St. br...
# 16      River/Stream  Right descending bank upstream of Cedar St. br...
# 17      River/Stream  Right descending bank upstream of Cedar St. br...
# 18      River/Stream  Right descending bank upstream of Cedar St. br...
# 19      River/Stream  Right descending bank upstream of Cedar St. br...
# 20      River/Stream  Right descending bank upstream of Cedar St. br...
# 21      River/Stream  Right descending bank upstream of Cedar St. br...
# 22      River/Stream  Right descending bank upstream of Cedar St. br...
# 23      River/Stream  Right descending bank upstream of Cedar St. br...
# 24      River/Stream  Right descending bank upstream of Cedar St. br...
# 25      River/Stream  Right descending bank upstream of Cedar St. br...
# 26      River/Stream  Right descending bank upstream of Cedar St. br...
# 27      River/Stream  Right descending bank upstream of Cedar St. br...
# 28      River/Stream  Right descending bank upstream of Cedar St. br...
# 29      River/Stream  Right descending bank upstream of Cedar St. br...
# ...              ...                                                ...
# 100611  River/Stream  Right descending bank upstream of Cedar St. br...
# 100612  River/Stream  Right descending bank upstream of Cedar St. br...
# 100613  River/Stream  Right descending bank upstream of Cedar St. br...
# 100614  River/Stream  Right descending bank upstream of Cedar St. br...
# 100615  River/Stream  Right descending bank upstream of Cedar St. br...
# 100616  River/Stream  Right descending bank upstream of Cedar St. br...
# 100617  River/Stream  Right descending bank upstream of Cedar St. br...
# 100618  River/Stream  Right descending bank upstream of Cedar St. br...
# 100619  River/Stream  Right descending bank upstream of Cedar St. br...
# 100620  River/Stream  Right descending bank upstream of Cedar St. br...
# 100621  River/Stream  Right descending bank upstream of Cedar St. br...
# 100622  River/Stream  Right descending bank upstream of Cedar St. br...
# 100623  River/Stream  Right descending bank upstream of Cedar St. br...
# 100624  River/Stream  Right descending bank upstream of Cedar St. br...
# 100625  River/Stream  Right descending bank upstream of Cedar St. br...
# 100626  River/Stream  Right descending bank upstream of Cedar St. br...
# 100627  River/Stream  Right descending bank upstream of Cedar St. br...
# 100628  River/Stream  Right descending bank upstream of Cedar St. br...
# 100629  River/Stream  Right descending bank upstream of Cedar St. br...
# 100630  River/Stream  Right descending bank upstream of Cedar St. br...
# 100631  River/Stream  Right descending bank upstream of Cedar St. br...
# 100632  River/Stream  Right descending bank upstream of Cedar St. br...
# 100633  River/Stream  Right descending bank upstream of Cedar St. br...
# 100634  River/Stream  Right descending bank upstream of Cedar St. br...
# 100635  River/Stream  Right descending bank upstream of Cedar St. br...
# 100636  River/Stream  Right descending bank upstream of Cedar St. br...
# 100637  River/Stream  Right descending bank upstream of Cedar St. br...
# 100638  River/Stream  Right descending bank upstream of Cedar St. br...
# 100639  River/Stream  Right descending bank upstream of Cedar St. br...
# 100640  River/Stream  Right descending bank upstream of Cedar St. br...
#
#             River_Name  RiverMile NavigationPool  NavMile  \
# 0       Illinois River      161.6         Peoria    161.6
# 1       Illinois River      161.6         Peoria    161.6
# 2       Illinois River      161.6         Peoria    161.6
# 3       Illinois River      161.6         Peoria    161.6
# 4       Illinois River      161.6         Peoria    161.6
# 5       Illinois River      161.6         Peoria    161.6
# 6       Illinois River      161.6         Peoria    161.6
# 7       Illinois River      161.6         Peoria    161.6
# 8       Illinois River      161.6         Peoria    161.6
# 9       Illinois River      161.6         Peoria    161.6
# 10      Illinois River      161.6         Peoria    161.6
# 11      Illinois River      161.6         Peoria    161.6
# 12      Illinois River      161.6         Peoria    161.6
# 13      Illinois River      161.6         Peoria    161.6
# 14      Illinois River      161.6         Peoria    161.6
# 15      Illinois River      161.6         Peoria    161.6
# 16      Illinois River      161.6         Peoria    161.6
# 17      Illinois River      161.6         Peoria    161.6
# 18      Illinois River      161.6         Peoria    161.6
# 19      Illinois River      161.6         Peoria    161.6
# 20      Illinois River      161.6         Peoria    161.6
# 21      Illinois River      161.6         Peoria    161.6
# 22      Illinois River      161.6         Peoria    161.6
# 23      Illinois River      161.6         Peoria    161.6
# 24      Illinois River      161.6         Peoria    161.6
# 25      Illinois River      161.6         Peoria    161.6
# 26      Illinois River      161.6         Peoria    161.6
# 27      Illinois River      161.6         Peoria    161.6
# 28      Illinois River      161.6         Peoria    161.6
# 29      Illinois River      161.6         Peoria    161.6
# ...                ...        ...            ...      ...
# 100611  Illinois River      161.6         Peoria    161.6
# 100612  Illinois River      161.6         Peoria    161.6
# 100613  Illinois River      161.6         Peoria    161.6
# 100614  Illinois River      161.6         Peoria    161.6
# 100615  Illinois River      161.6         Peoria    161.6
# 100616  Illinois River      161.6         Peoria    161.6
# 100617  Illinois River      161.6         Peoria    161.6
# 100618  Illinois River      161.6         Peoria    161.6
# 100619  Illinois River      161.6         Peoria    161.6
# 100620  Illinois River      161.6         Peoria    161.6
# 100621  Illinois River      161.6         Peoria    161.6
# 100622  Illinois River      161.6         Peoria    161.6
# 100623  Illinois River      161.6         Peoria    161.6
# 100624  Illinois River      161.6         Peoria    161.6
# 100625  Illinois River      161.6         Peoria    161.6
# 100626  Illinois River      161.6         Peoria    161.6
# 100627  Illinois River      161.6         Peoria    161.6
# 100628  Illinois River      161.6         Peoria    161.6
# 100629  Illinois River      161.6         Peoria    161.6
# 100630  Illinois River      161.6         Peoria    161.6
# 100631  Illinois River      161.6         Peoria    161.6
# 100632  Illinois River      161.6         Peoria    161.6
# 100633  Illinois River      161.6         Peoria    161.6
# 100634  Illinois River      161.6         Peoria    161.6
# 100635  Illinois River      161.6         Peoria    161.6
# 100636  Illinois River      161.6         Peoria    161.6
# 100637  Illinois River      161.6         Peoria    161.6
# 100638  Illinois River      161.6         Peoria    161.6
# 100639  Illinois River      161.6         Peoria    161.6
# 100640  Illinois River      161.6         Peoria    161.6
#
#                               ...                          ResultValue(mg/L)  \
# 0                             ...                                      13.00
# 1                             ...                                      11.40
# 2                             ...                                      12.45
# 3                             ...                                      13.10
# 4                             ...                                      12.45
# 5                             ...                                      12.35
# 6                             ...                                      12.95
# 7                             ...                                      11.40
# 8                             ...                                      12.35
# 9                             ...                                      12.30
# 10                            ...                                      12.10
# 11                            ...                                      11.40
# 12                            ...                                      11.95
# 13                            ...                                      11.95
# 14                            ...                                      11.80
# 15                            ...                                      12.75
# 16                            ...                                      12.35
# 17                            ...                                      11.90
# 18                            ...                                      12.15
# 19                            ...                                      12.50
# 20                            ...                                      12.20
# 21                            ...                                      12.05
# 22                            ...                                      13.00
# 23                            ...                                      13.45
# 24                            ...                                      12.90
# 25                            ...                                      11.95
# 26                            ...                                      10.80
# 27                            ...                                       9.60
# 28                            ...                                       9.10
# 29                            ...                                       8.95
# ...                           ...                                        ...
# 100611                        ...                                       6.62
# 100612                        ...                                       5.15
# 100613                        ...                                       4.90
# 100614                        ...                                       5.05
# 100615                        ...                                       8.92
# 100616                        ...                                       6.10
# 100617                        ...                                       8.25
# 100618                        ...                                       9.20
# 100619                        ...                                      11.90
# 100620                        ...                                      14.00
# 100621                        ...                                      10.55
# 100622                        ...                                       9.35
# 100623                        ...                                      11.05
# 100624                        ...                                       7.80
# 100625                        ...                                       6.75
# 100626                        ...                                       3.65
# 100627                        ...                                       6.10
# 100628                        ...                                       5.35
# 100629                        ...                                       4.80
# 100630                        ...                                       5.94
# 100631                        ...                                       4.24
# 100632                        ...                                       4.60
# 100633                        ...                                       4.30
# 100634                        ...                                       5.33
# 100635                        ...                                       7.50
# 100636                        ...                                       8.40
# 100637                        ...                                      11.30
# 100638                        ...                                      10.04
# 100639                        ...                                      11.10
# 100640                        ...                                      11.60
#
#         Result_Unit         Result_Lab_Name Result_Lab_Comment  \
# 0              mg/L  ISWS Peoria Laboratory                NaN
# 1              mg/L  ISWS Peoria Laboratory                NaN
# 2              mg/L  ISWS Peoria Laboratory                NaN
# 3              mg/L  ISWS Peoria Laboratory                NaN
# 4              mg/L  ISWS Peoria Laboratory                NaN
# 5              mg/L  ISWS Peoria Laboratory                NaN
# 6              mg/L  ISWS Peoria Laboratory                NaN
# 7              mg/L  ISWS Peoria Laboratory                NaN
# 8              mg/L  ISWS Peoria Laboratory                NaN
# 9              mg/L  ISWS Peoria Laboratory                NaN
# 10             mg/L  ISWS Peoria Laboratory                NaN
# 11             mg/L  ISWS Peoria Laboratory                NaN
# 12             mg/L  ISWS Peoria Laboratory                NaN
# 13             mg/L  ISWS Peoria Laboratory                NaN
# 14             mg/L  ISWS Peoria Laboratory                NaN
# 15             mg/L  ISWS Peoria Laboratory                NaN
# 16             mg/L  ISWS Peoria Laboratory                NaN
# 17             mg/L  ISWS Peoria Laboratory                NaN
# 18             mg/L  ISWS Peoria Laboratory                NaN
# 19             mg/L  ISWS Peoria Laboratory                NaN
# 20             mg/L  ISWS Peoria Laboratory                NaN
# 21             mg/L  ISWS Peoria Laboratory                NaN
# 22             mg/L  ISWS Peoria Laboratory                NaN
# 23             mg/L  ISWS Peoria Laboratory                NaN
# 24             mg/L  ISWS Peoria Laboratory                NaN
# 25             mg/L  ISWS Peoria Laboratory                NaN
# 26             mg/L  ISWS Peoria Laboratory                NaN
# 27             mg/L  ISWS Peoria Laboratory                NaN
# 28             mg/L  ISWS Peoria Laboratory                NaN
# 29             mg/L  ISWS Peoria Laboratory                NaN
# ...             ...                     ...                ...
# 100611         mg/L  ISWS Peoria Laboratory                NaN
# 100612         mg/L  ISWS Peoria Laboratory                NaN
# 100613         mg/L  ISWS Peoria Laboratory                NaN
# 100614         mg/L  ISWS Peoria Laboratory                NaN
# 100615         mg/L  ISWS Peoria Laboratory                NaN
# 100616         mg/L  ISWS Peoria Laboratory                NaN
# 100617         mg/L  ISWS Peoria Laboratory                NaN
# 100618         mg/L  ISWS Peoria Laboratory                NaN
# 100619         mg/L  ISWS Peoria Laboratory                NaN
# 100620         mg/L  ISWS Peoria Laboratory                NaN
# 100621         mg/L  ISWS Peoria Laboratory                NaN
# 100622         mg/L  ISWS Peoria Laboratory                NaN
# 100623         mg/L  ISWS Peoria Laboratory                NaN
# 100624         mg/L  ISWS Peoria Laboratory                NaN
# 100625         mg/L  ISWS Peoria Laboratory                NaN
# 100626         mg/L  ISWS Peoria Laboratory                NaN
# 100627         mg/L  ISWS Peoria Laboratory                NaN
# 100628         mg/L  ISWS Peoria Laboratory                NaN
# 100629         mg/L  ISWS Peoria Laboratory                NaN
# 100630         mg/L  ISWS Peoria Laboratory                NaN
# 100631         mg/L  ISWS Peoria Laboratory                NaN
# 100632         mg/L  ISWS Peoria Laboratory                NaN
# 100633         mg/L  ISWS Peoria Laboratory                NaN
# 100634         mg/L  ISWS Peoria Laboratory                NaN
# 100635         mg/L  ISWS Peoria Laboratory                NaN
# 100636         mg/L  ISWS Peoria Laboratory                NaN
# 100637         mg/L  ISWS Peoria Laboratory                NaN
# 100638         mg/L  ISWS Peoria Laboratory                NaN
# 100639         mg/L  ISWS Peoria Laboratory                NaN
# 100640         mg/L  ISWS Peoria Laboratory                NaN
#
#         CharacteristicID           Chr_Name ANLMTH_ID  \
# 0                     18  Oxygen, Dissolved        67
# 1                     18  Oxygen, Dissolved        67
# 2                     18  Oxygen, Dissolved        67
# 3                     18  Oxygen, Dissolved        67
# 4                     18  Oxygen, Dissolved        67
# 5                     18  Oxygen, Dissolved        67
# 6                     18  Oxygen, Dissolved        67
# 7                     18  Oxygen, Dissolved        67
# 8                     18  Oxygen, Dissolved        67
# 9                     18  Oxygen, Dissolved        67
# 10                    18  Oxygen, Dissolved        67
# 11                    18  Oxygen, Dissolved        67
# 12                    18  Oxygen, Dissolved        67
# 13                    18  Oxygen, Dissolved        67
# 14                    18  Oxygen, Dissolved        67
# 15                    18  Oxygen, Dissolved        67
# 16                    18  Oxygen, Dissolved        67
# 17                    18  Oxygen, Dissolved        67
# 18                    18  Oxygen, Dissolved        67
# 19                    18  Oxygen, Dissolved        67
# 20                    18  Oxygen, Dissolved        67
# 21                    18  Oxygen, Dissolved        67
# 22                    18  Oxygen, Dissolved        67
# 23                    18  Oxygen, Dissolved        67
# 24                    18  Oxygen, Dissolved        67
# 25                    18  Oxygen, Dissolved        67
# 26                    18  Oxygen, Dissolved        67
# 27                    18  Oxygen, Dissolved        67
# 28                    18  Oxygen, Dissolved        67
# 29                    18  Oxygen, Dissolved        67
# ...                  ...                ...       ...
# 100611                18  Oxygen, Dissolved        67
# 100612                18  Oxygen, Dissolved        67
# 100613                18  Oxygen, Dissolved        67
# 100614                18  Oxygen, Dissolved        67
# 100615                18  Oxygen, Dissolved        67
# 100616                18  Oxygen, Dissolved        67
# 100617                18  Oxygen, Dissolved        67
# 100618                18  Oxygen, Dissolved        67
# 100619                18  Oxygen, Dissolved        67
# 100620                18  Oxygen, Dissolved        67
# 100621                18  Oxygen, Dissolved        67
# 100622                18  Oxygen, Dissolved        67
# 100623                18  Oxygen, Dissolved        67
# 100624                18  Oxygen, Dissolved        67
# 100625                18  Oxygen, Dissolved        67
# 100626                18  Oxygen, Dissolved        67
# 100627                18  Oxygen, Dissolved        67
# 100628                18  Oxygen, Dissolved        67
# 100629                18  Oxygen, Dissolved        67
# 100630                18  Oxygen, Dissolved        67
# 100631                18  Oxygen, Dissolved        67
# 100632                18  Oxygen, Dissolved        67
# 100633                18  Oxygen, Dissolved        67
# 100634                18  Oxygen, Dissolved        67
# 100635                18  Oxygen, Dissolved        67
# 100636                18  Oxygen, Dissolved        67
# 100637                18  Oxygen, Dissolved        67
# 100638                18  Oxygen, Dissolved        67
# 100639                18  Oxygen, Dissolved        67
# 100640                18  Oxygen, Dissolved        67
#
#                             ANLMTH_Name          ANLMTH_Desc  \
# 0       Oxygen (Dissolved) by Volumetry  Azide modification
# 1       Oxygen (Dissolved) by Volumetry  Azide modification
# 2       Oxygen (Dissolved) by Volumetry  Azide modification
# 3       Oxygen (Dissolved) by Volumetry  Azide modification
# 4       Oxygen (Dissolved) by Volumetry  Azide modification
# 5       Oxygen (Dissolved) by Volumetry  Azide modification
# 6       Oxygen (Dissolved) by Volumetry  Azide modification
# 7       Oxygen (Dissolved) by Volumetry  Azide modification
# 8       Oxygen (Dissolved) by Volumetry  Azide modification
# 9       Oxygen (Dissolved) by Volumetry  Azide modification
# 10      Oxygen (Dissolved) by Volumetry  Azide modification
# 11      Oxygen (Dissolved) by Volumetry  Azide modification
# 12      Oxygen (Dissolved) by Volumetry  Azide modification
# 13      Oxygen (Dissolved) by Volumetry  Azide modification
# 14      Oxygen (Dissolved) by Volumetry  Azide modification
# 15      Oxygen (Dissolved) by Volumetry  Azide modification
# 16      Oxygen (Dissolved) by Volumetry  Azide modification
# 17      Oxygen (Dissolved) by Volumetry  Azide modification
# 18      Oxygen (Dissolved) by Volumetry  Azide modification
# 19      Oxygen (Dissolved) by Volumetry  Azide modification
# 20      Oxygen (Dissolved) by Volumetry  Azide modification
# 21      Oxygen (Dissolved) by Volumetry  Azide modification
# 22      Oxygen (Dissolved) by Volumetry  Azide modification
# 23      Oxygen (Dissolved) by Volumetry  Azide modification
# 24      Oxygen (Dissolved) by Volumetry  Azide modification
# 25      Oxygen (Dissolved) by Volumetry  Azide modification
# 26      Oxygen (Dissolved) by Volumetry  Azide modification
# 27      Oxygen (Dissolved) by Volumetry  Azide modification
# 28      Oxygen (Dissolved) by Volumetry  Azide modification
# 29      Oxygen (Dissolved) by Volumetry  Azide modification
# ...                                 ...                  ...
# 100611  Oxygen (Dissolved) by Volumetry  Azide modification
# 100612  Oxygen (Dissolved) by Volumetry  Azide modification
# 100613  Oxygen (Dissolved) by Volumetry  Azide modification
# 100614  Oxygen (Dissolved) by Volumetry  Azide modification
# 100615  Oxygen (Dissolved) by Volumetry  Azide modification
# 100616  Oxygen (Dissolved) by Volumetry  Azide modification
# 100617  Oxygen (Dissolved) by Volumetry  Azide modification
# 100618  Oxygen (Dissolved) by Volumetry  Azide modification
# 100619  Oxygen (Dissolved) by Volumetry  Azide modification
# 100620  Oxygen (Dissolved) by Volumetry  Azide modification
# 100621  Oxygen (Dissolved) by Volumetry  Azide modification
# 100622  Oxygen (Dissolved) by Volumetry  Azide modification
# 100623  Oxygen (Dissolved) by Volumetry  Azide modification
# 100624  Oxygen (Dissolved) by Volumetry  Azide modification
# 100625  Oxygen (Dissolved) by Volumetry  Azide modification
# 100626  Oxygen (Dissolved) by Volumetry  Azide modification
# 100627  Oxygen (Dissolved) by Volumetry  Azide modification
# 100628  Oxygen (Dissolved) by Volumetry  Azide modification
# 100629  Oxygen (Dissolved) by Volumetry  Azide modification
# 100630  Oxygen (Dissolved) by Volumetry  Azide modification
# 100631  Oxygen (Dissolved) by Volumetry  Azide modification
# 100632  Oxygen (Dissolved) by Volumetry  Azide modification
# 100633  Oxygen (Dissolved) by Volumetry  Azide modification
# 100634  Oxygen (Dissolved) by Volumetry  Azide modification
# 100635  Oxygen (Dissolved) by Volumetry  Azide modification
# 100636  Oxygen (Dissolved) by Volumetry  Azide modification
# 100637  Oxygen (Dissolved) by Volumetry  Azide modification
# 100638  Oxygen (Dissolved) by Volumetry  Azide modification
# 100639  Oxygen (Dissolved) by Volumetry  Azide modification
# 100640  Oxygen (Dissolved) by Volumetry  Azide modification
#
#                                                ANLMTH_Ref
# 0       American Public Health Association. 1975. Stan...
# 1       American Public Health Association. 1975. Stan...
# 2       American Public Health Association. 1975. Stan...
# 3       American Public Health Association. 1975. Stan...
# 4       American Public Health Association. 1975. Stan...
# 5       American Public Health Association. 1975. Stan...
# 6       American Public Health Association. 1975. Stan...
# 7       American Public Health Association. 1975. Stan...
# 8       American Public Health Association. 1975. Stan...
# 9       American Public Health Association. 1975. Stan...
# 10      American Public Health Association. 1975. Stan...
# 11      American Public Health Association. 1975. Stan...
# 12      American Public Health Association. 1975. Stan...
# 13      American Public Health Association. 1975. Stan...
# 14      American Public Health Association. 1975. Stan...
# 15      American Public Health Association. 1975. Stan...
# 16      American Public Health Association. 1975. Stan...
# 17      American Public Health Association. 1975. Stan...
# 18      American Public Health Association. 1975. Stan...
# 19      American Public Health Association. 1975. Stan...
# 20      American Public Health Association. 1975. Stan...
# 21      American Public Health Association. 1975. Stan...
# 22      American Public Health Association. 1975. Stan...
# 23      American Public Health Association. 1975. Stan...
# 24      American Public Health Association. 1975. Stan...
# 25      American Public Health Association. 1975. Stan...
# 26      American Public Health Association. 1975. Stan...
# 27      American Public Health Association. 1975. Stan...
# 28      American Public Health Association. 1975. Stan...
# 29      American Public Health Association. 1975. Stan...
# ...                                                   ...
# 100611  American Public Health Association. 1975. Stan...
# 100612  American Public Health Association. 1975. Stan...
# 100613  American Public Health Association. 1975. Stan...
# 100614  American Public Health Association. 1975. Stan...
# 100615  American Public Health Association. 1975. Stan...
# 100616  American Public Health Association. 1975. Stan...
# 100617  American Public Health Association. 1975. Stan...
# 100618  American Public Health Association. 1975. Stan...
# 100619  American Public Health Association. 1975. Stan...
# 100620  American Public Health Association. 1975. Stan...
# 100621  American Public Health Association. 1975. Stan...
# 100622  American Public Health Association. 1975. Stan...
# 100623  American Public Health Association. 1975. Stan...
# 100624  American Public Health Association. 1975. Stan...
# 100625  American Public Health Association. 1975. Stan...
# 100626  American Public Health Association. 1975. Stan...
# 100627  American Public Health Association. 1975. Stan...
# 100628  American Public Health Association. 1975. Stan...
# 100629  American Public Health Association. 1975. Stan...
# 100630  American Public Health Association. 1975. Stan...
# 100631  American Public Health Association. 1975. Stan...
# 100632  American Public Health Association. 1975. Stan...
# 100633  American Public Health Association. 1975. Stan...
# 100634  American Public Health Association. 1975. Stan...
# 100635  American Public Health Association. 1975. Stan...
# 100636  American Public Health Association. 1975. Stan...
# 100637  American Public Health Association. 1975. Stan...
# 100638  American Public Health Association. 1975. Stan...
# 100639  American Public Health Association. 1975. Stan...
# 100640  American Public Health Association. 1975. Stan...
#
# [100641 rows x 38 columns]

# %%
df['ResultValue(mg/L)']
# Out:
# 0     13.00
# 1     11.40
# 2     12.45
# 3     13.10
# 4     12.45
# 5     12.35
# 6     12.95
# 7     11.40
# 8     12.35
# 9     12.30
# 10    12.10
# 11    11.40
# 12    11.95
# 13    11.95
# 14    11.80
# ...
# 100626     3.65
# 100627     6.10
# 100628     5.35
# 100629     4.80
# 100630     5.94
# 100631     4.24
# 100632     4.60
# 100633     4.30
# 100634     5.33
# 100635     7.50
# 100636     8.40
# 100637    11.30
# 100638    10.04
# 100639    11.10
# 100640    11.60
# Name: ResultValue(mg/L), Length: 100641, dtype: float64

# %%
df[:100640]
# Out:
#         ProjectID                                  Prj_Name  \
# 0               3  ISWS Illinois River at Peoria Monitoring
# 1               3  ISWS Illinois River at Peoria Monitoring
# 2               3  ISWS Illinois River at Peoria Monitoring
# 3               3  ISWS Illinois River at Peoria Monitoring
# 4               3  ISWS Illinois River at Peoria Monitoring
# 5               3  ISWS Illinois River at Peoria Monitoring
# 6               3  ISWS Illinois River at Peoria Monitoring
# 7               3  ISWS Illinois River at Peoria Monitoring
# 8               3  ISWS Illinois River at Peoria Monitoring
# 9               3  ISWS Illinois River at Peoria Monitoring
# 10              3  ISWS Illinois River at Peoria Monitoring
# 11              3  ISWS Illinois River at Peoria Monitoring
# 12              3  ISWS Illinois River at Peoria Monitoring
# 13              3  ISWS Illinois River at Peoria Monitoring
# 14              3  ISWS Illinois River at Peoria Monitoring
# 15              3  ISWS Illinois River at Peoria Monitoring
# 16              3  ISWS Illinois River at Peoria Monitoring
# 17              3  ISWS Illinois River at Peoria Monitoring
# 18              3  ISWS Illinois River at Peoria Monitoring
# 19              3  ISWS Illinois River at Peoria Monitoring
# 20              3  ISWS Illinois River at Peoria Monitoring
# 21              3  ISWS Illinois River at Peoria Monitoring
# 22              3  ISWS Illinois River at Peoria Monitoring
# 23              3  ISWS Illinois River at Peoria Monitoring
# 24              3  ISWS Illinois River at Peoria Monitoring
# 25              3  ISWS Illinois River at Peoria Monitoring
# 26              3  ISWS Illinois River at Peoria Monitoring
# 27              3  ISWS Illinois River at Peoria Monitoring
# 28              3  ISWS Illinois River at Peoria Monitoring
# 29              3  ISWS Illinois River at Peoria Monitoring
# ...           ...                                       ...
# 100610          3  ISWS Illinois River at Peoria Monitoring
# 100611          3  ISWS Illinois River at Peoria Monitoring
# 100612          3  ISWS Illinois River at Peoria Monitoring
# 100613          3  ISWS Illinois River at Peoria Monitoring
# 100614          3  ISWS Illinois River at Peoria Monitoring
# 100615          3  ISWS Illinois River at Peoria Monitoring
# 100616          3  ISWS Illinois River at Peoria Monitoring
# 100617          3  ISWS Illinois River at Peoria Monitoring
# 100618          3  ISWS Illinois River at Peoria Monitoring
# 100619          3  ISWS Illinois River at Peoria Monitoring
# 100620          3  ISWS Illinois River at Peoria Monitoring
# 100621          3  ISWS Illinois River at Peoria Monitoring
# 100622          3  ISWS Illinois River at Peoria Monitoring
# 100623          3  ISWS Illinois River at Peoria Monitoring
# 100624          3  ISWS Illinois River at Peoria Monitoring
# 100625          3  ISWS Illinois River at Peoria Monitoring
# 100626          3  ISWS Illinois River at Peoria Monitoring
# 100627          3  ISWS Illinois River at Peoria Monitoring
# 100628          3  ISWS Illinois River at Peoria Monitoring
# 100629          3  ISWS Illinois River at Peoria Monitoring
# 100630          3  ISWS Illinois River at Peoria Monitoring
# 100631          3  ISWS Illinois River at Peoria Monitoring
# 100632          3  ISWS Illinois River at Peoria Monitoring
# 100633          3  ISWS Illinois River at Peoria Monitoring
# 100634          3  ISWS Illinois River at Peoria Monitoring
# 100635          3  ISWS Illinois River at Peoria Monitoring
# 100636          3  ISWS Illinois River at Peoria Monitoring
# 100637          3  ISWS Illinois River at Peoria Monitoring
# 100638          3  ISWS Illinois River at Peoria Monitoring
# 100639          3  ISWS Illinois River at Peoria Monitoring
#
#                                           Prj_Description  MLocID  \
# 0       A long-term monitoring program collecting wate...  03-001
# 1       A long-term monitoring program collecting wate...  03-001
# 2       A long-term monitoring program collecting wate...  03-001
# 3       A long-term monitoring program collecting wate...  03-001
# 4       A long-term monitoring program collecting wate...  03-001
# 5       A long-term monitoring program collecting wate...  03-001
# 6       A long-term monitoring program collecting wate...  03-001
# 7       A long-term monitoring program collecting wate...  03-001
# 8       A long-term monitoring program collecting wate...  03-001
# 9       A long-term monitoring program collecting wate...  03-001
# 10      A long-term monitoring program collecting wate...  03-001
# 11      A long-term monitoring program collecting wate...  03-001
# 12      A long-term monitoring program collecting wate...  03-001
# 13      A long-term monitoring program collecting wate...  03-001
# 14      A long-term monitoring program collecting wate...  03-001
# 15      A long-term monitoring program collecting wate...  03-001
# 16      A long-term monitoring program collecting wate...  03-001
# 17      A long-term monitoring program collecting wate...  03-001
# 18      A long-term monitoring program collecting wate...  03-001
# 19      A long-term monitoring program collecting wate...  03-001
# 20      A long-term monitoring program collecting wate...  03-001
# 21      A long-term monitoring program collecting wate...  03-001
# 22      A long-term monitoring program collecting wate...  03-001
# 23      A long-term monitoring program collecting wate...  03-001
# 24      A long-term monitoring program collecting wate...  03-001
# 25      A long-term monitoring program collecting wate...  03-001
# 26      A long-term monitoring program collecting wate...  03-001
# 27      A long-term monitoring program collecting wate...  03-001
# 28      A long-term monitoring program collecting wate...  03-001
# 29      A long-term monitoring program collecting wate...  03-001
# ...                                                   ...     ...
# 100610  A long-term monitoring program collecting wate...  03-001
# 100611  A long-term monitoring program collecting wate...  03-001
# 100612  A long-term monitoring program collecting wate...  03-001
# 100613  A long-term monitoring program collecting wate...  03-001
# 100614  A long-term monitoring program collecting wate...  03-001
# 100615  A long-term monitoring program collecting wate...  03-001
# 100616  A long-term monitoring program collecting wate...  03-001
# 100617  A long-term monitoring program collecting wate...  03-001
# 100618  A long-term monitoring program collecting wate...  03-001
# 100619  A long-term monitoring program collecting wate...  03-001
# 100620  A long-term monitoring program collecting wate...  03-001
# 100621  A long-term monitoring program collecting wate...  03-001
# 100622  A long-term monitoring program collecting wate...  03-001
# 100623  A long-term monitoring program collecting wate...  03-001
# 100624  A long-term monitoring program collecting wate...  03-001
# 100625  A long-term monitoring program collecting wate...  03-001
# 100626  A long-term monitoring program collecting wate...  03-001
# 100627  A long-term monitoring program collecting wate...  03-001
# 100628  A long-term monitoring program collecting wate...  03-001
# 100629  A long-term monitoring program collecting wate...  03-001
# 100630  A long-term monitoring program collecting wate...  03-001
# 100631  A long-term monitoring program collecting wate...  03-001
# 100632  A long-term monitoring program collecting wate...  03-001
# 100633  A long-term monitoring program collecting wate...  03-001
# 100634  A long-term monitoring program collecting wate...  03-001
# 100635  A long-term monitoring program collecting wate...  03-001
# 100636  A long-term monitoring program collecting wate...  03-001
# 100637  A long-term monitoring program collecting wate...  03-001
# 100638  A long-term monitoring program collecting wate...  03-001
# 100639  A long-term monitoring program collecting wate...  03-001
#
#            MLoc_Type                                   MLoc_Description  \
# 0       River/Stream  Right descending bank upstream of Cedar St. br...
# 1       River/Stream  Right descending bank upstream of Cedar St. br...
# 2       River/Stream  Right descending bank upstream of Cedar St. br...
# 3       River/Stream  Right descending bank upstream of Cedar St. br...
# 4       River/Stream  Right descending bank upstream of Cedar St. br...
# 5       River/Stream  Right descending bank upstream of Cedar St. br...
# 6       River/Stream  Right descending bank upstream of Cedar St. br...
# 7       River/Stream  Right descending bank upstream of Cedar St. br...
# 8       River/Stream  Right descending bank upstream of Cedar St. br...
# 9       River/Stream  Right descending bank upstream of Cedar St. br...
# 10      River/Stream  Right descending bank upstream of Cedar St. br...
# 11      River/Stream  Right descending bank upstream of Cedar St. br...
# 12      River/Stream  Right descending bank upstream of Cedar St. br...
# 13      River/Stream  Right descending bank upstream of Cedar St. br...
# 14      River/Stream  Right descending bank upstream of Cedar St. br...
# 15      River/Stream  Right descending bank upstream of Cedar St. br...
# 16      River/Stream  Right descending bank upstream of Cedar St. br...
# 17      River/Stream  Right descending bank upstream of Cedar St. br...
# 18      River/Stream  Right descending bank upstream of Cedar St. br...
# 19      River/Stream  Right descending bank upstream of Cedar St. br...
# 20      River/Stream  Right descending bank upstream of Cedar St. br...
# 21      River/Stream  Right descending bank upstream of Cedar St. br...
# 22      River/Stream  Right descending bank upstream of Cedar St. br...
# 23      River/Stream  Right descending bank upstream of Cedar St. br...
# 24      River/Stream  Right descending bank upstream of Cedar St. br...
# 25      River/Stream  Right descending bank upstream of Cedar St. br...
# 26      River/Stream  Right descending bank upstream of Cedar St. br...
# 27      River/Stream  Right descending bank upstream of Cedar St. br...
# 28      River/Stream  Right descending bank upstream of Cedar St. br...
# 29      River/Stream  Right descending bank upstream of Cedar St. br...
# ...              ...                                                ...
# 100610  River/Stream  Right descending bank upstream of Cedar St. br...
# 100611  River/Stream  Right descending bank upstream of Cedar St. br...
# 100612  River/Stream  Right descending bank upstream of Cedar St. br...
# 100613  River/Stream  Right descending bank upstream of Cedar St. br...
# 100614  River/Stream  Right descending bank upstream of Cedar St. br...
# 100615  River/Stream  Right descending bank upstream of Cedar St. br...
# 100616  River/Stream  Right descending bank upstream of Cedar St. br...
# 100617  River/Stream  Right descending bank upstream of Cedar St. br...
# 100618  River/Stream  Right descending bank upstream of Cedar St. br...
# 100619  River/Stream  Right descending bank upstream of Cedar St. br...
# 100620  River/Stream  Right descending bank upstream of Cedar St. br...
# 100621  River/Stream  Right descending bank upstream of Cedar St. br...
# 100622  River/Stream  Right descending bank upstream of Cedar St. br...
# 100623  River/Stream  Right descending bank upstream of Cedar St. br...
# 100624  River/Stream  Right descending bank upstream of Cedar St. br...
# 100625  River/Stream  Right descending bank upstream of Cedar St. br...
# 100626  River/Stream  Right descending bank upstream of Cedar St. br...
# 100627  River/Stream  Right descending bank upstream of Cedar St. br...
# 100628  River/Stream  Right descending bank upstream of Cedar St. br...
# 100629  River/Stream  Right descending bank upstream of Cedar St. br...
# 100630  River/Stream  Right descending bank upstream of Cedar St. br...
# 100631  River/Stream  Right descending bank upstream of Cedar St. br...
# 100632  River/Stream  Right descending bank upstream of Cedar St. br...
# 100633  River/Stream  Right descending bank upstream of Cedar St. br...
# 100634  River/Stream  Right descending bank upstream of Cedar St. br...
# 100635  River/Stream  Right descending bank upstream of Cedar St. br...
# 100636  River/Stream  Right descending bank upstream of Cedar St. br...
# 100637  River/Stream  Right descending bank upstream of Cedar St. br...
# 100638  River/Stream  Right descending bank upstream of Cedar St. br...
# 100639  River/Stream  Right descending bank upstream of Cedar St. br...
#
#             River_Name  RiverMile NavigationPool  NavMile  \
# 0       Illinois River      161.6         Peoria    161.6
# 1       Illinois River      161.6         Peoria    161.6
# 2       Illinois River      161.6         Peoria    161.6
# 3       Illinois River      161.6         Peoria    161.6
# 4       Illinois River      161.6         Peoria    161.6
# 5       Illinois River      161.6         Peoria    161.6
# 6       Illinois River      161.6         Peoria    161.6
# 7       Illinois River      161.6         Peoria    161.6
# 8       Illinois River      161.6         Peoria    161.6
# 9       Illinois River      161.6         Peoria    161.6
# 10      Illinois River      161.6         Peoria    161.6
# 11      Illinois River      161.6         Peoria    161.6
# 12      Illinois River      161.6         Peoria    161.6
# 13      Illinois River      161.6         Peoria    161.6
# 14      Illinois River      161.6         Peoria    161.6
# 15      Illinois River      161.6         Peoria    161.6
# 16      Illinois River      161.6         Peoria    161.6
# 17      Illinois River      161.6         Peoria    161.6
# 18      Illinois River      161.6         Peoria    161.6
# 19      Illinois River      161.6         Peoria    161.6
# 20      Illinois River      161.6         Peoria    161.6
# 21      Illinois River      161.6         Peoria    161.6
# 22      Illinois River      161.6         Peoria    161.6
# 23      Illinois River      161.6         Peoria    161.6
# 24      Illinois River      161.6         Peoria    161.6
# 25      Illinois River      161.6         Peoria    161.6
# 26      Illinois River      161.6         Peoria    161.6
# 27      Illinois River      161.6         Peoria    161.6
# 28      Illinois River      161.6         Peoria    161.6
# 29      Illinois River      161.6         Peoria    161.6
# ...                ...        ...            ...      ...
# 100610  Illinois River      161.6         Peoria    161.6
# 100611  Illinois River      161.6         Peoria    161.6
# 100612  Illinois River      161.6         Peoria    161.6
# 100613  Illinois River      161.6         Peoria    161.6
# 100614  Illinois River      161.6         Peoria    161.6
# 100615  Illinois River      161.6         Peoria    161.6
# 100616  Illinois River      161.6         Peoria    161.6
# 100617  Illinois River      161.6         Peoria    161.6
# 100618  Illinois River      161.6         Peoria    161.6
# 100619  Illinois River      161.6         Peoria    161.6
# 100620  Illinois River      161.6         Peoria    161.6
# 100621  Illinois River      161.6         Peoria    161.6
# 100622  Illinois River      161.6         Peoria    161.6
# 100623  Illinois River      161.6         Peoria    161.6
# 100624  Illinois River      161.6         Peoria    161.6
# 100625  Illinois River      161.6         Peoria    161.6
# 100626  Illinois River      161.6         Peoria    161.6
# 100627  Illinois River      161.6         Peoria    161.6
# 100628  Illinois River      161.6         Peoria    161.6
# 100629  Illinois River      161.6         Peoria    161.6
# 100630  Illinois River      161.6         Peoria    161.6
# 100631  Illinois River      161.6         Peoria    161.6
# 100632  Illinois River      161.6         Peoria    161.6
# 100633  Illinois River      161.6         Peoria    161.6
# 100634  Illinois River      161.6         Peoria    161.6
# 100635  Illinois River      161.6         Peoria    161.6
# 100636  Illinois River      161.6         Peoria    161.6
# 100637  Illinois River      161.6         Peoria    161.6
# 100638  Illinois River      161.6         Peoria    161.6
# 100639  Illinois River      161.6         Peoria    161.6
#
#                               ...                          ResultValue(mg/L)  \
# 0                             ...                                      13.00
# 1                             ...                                      11.40
# 2                             ...                                      12.45
# 3                             ...                                      13.10
# 4                             ...                                      12.45
# 5                             ...                                      12.35
# 6                             ...                                      12.95
# 7                             ...                                      11.40
# 8                             ...                                      12.35
# 9                             ...                                      12.30
# 10                            ...                                      12.10
# 11                            ...                                      11.40
# 12                            ...                                      11.95
# 13                            ...                                      11.95
# 14                            ...                                      11.80
# 15                            ...                                      12.75
# 16                            ...                                      12.35
# 17                            ...                                      11.90
# 18                            ...                                      12.15
# 19                            ...                                      12.50
# 20                            ...                                      12.20
# 21                            ...                                      12.05
# 22                            ...                                      13.00
# 23                            ...                                      13.45
# 24                            ...                                      12.90
# 25                            ...                                      11.95
# 26                            ...                                      10.80
# 27                            ...                                       9.60
# 28                            ...                                       9.10
# 29                            ...                                       8.95
# ...                           ...                                        ...
# 100610                        ...                                       7.11
# 100611                        ...                                       6.62
# 100612                        ...                                       5.15
# 100613                        ...                                       4.90
# 100614                        ...                                       5.05
# 100615                        ...                                       8.92
# 100616                        ...                                       6.10
# 100617                        ...                                       8.25
# 100618                        ...                                       9.20
# 100619                        ...                                      11.90
# 100620                        ...                                      14.00
# 100621                        ...                                      10.55
# 100622                        ...                                       9.35
# 100623                        ...                                      11.05
# 100624                        ...                                       7.80
# 100625                        ...                                       6.75
# 100626                        ...                                       3.65
# 100627                        ...                                       6.10
# 100628                        ...                                       5.35
# 100629                        ...                                       4.80
# 100630                        ...                                       5.94
# 100631                        ...                                       4.24
# 100632                        ...                                       4.60
# 100633                        ...                                       4.30
# 100634                        ...                                       5.33
# 100635                        ...                                       7.50
# 100636                        ...                                       8.40
# 100637                        ...                                      11.30
# 100638                        ...                                      10.04
# 100639                        ...                                      11.10
#
#         Result_Unit         Result_Lab_Name Result_Lab_Comment  \
# 0              mg/L  ISWS Peoria Laboratory                NaN
# 1              mg/L  ISWS Peoria Laboratory                NaN
# 2              mg/L  ISWS Peoria Laboratory                NaN
# 3              mg/L  ISWS Peoria Laboratory                NaN
# 4              mg/L  ISWS Peoria Laboratory                NaN
# 5              mg/L  ISWS Peoria Laboratory                NaN
# 6              mg/L  ISWS Peoria Laboratory                NaN
# 7              mg/L  ISWS Peoria Laboratory                NaN
# 8              mg/L  ISWS Peoria Laboratory                NaN
# 9              mg/L  ISWS Peoria Laboratory                NaN
# 10             mg/L  ISWS Peoria Laboratory                NaN
# 11             mg/L  ISWS Peoria Laboratory                NaN
# 12             mg/L  ISWS Peoria Laboratory                NaN
# 13             mg/L  ISWS Peoria Laboratory                NaN
# 14             mg/L  ISWS Peoria Laboratory                NaN
# 15             mg/L  ISWS Peoria Laboratory                NaN
# 16             mg/L  ISWS Peoria Laboratory                NaN
# 17             mg/L  ISWS Peoria Laboratory                NaN
# 18             mg/L  ISWS Peoria Laboratory                NaN
# 19             mg/L  ISWS Peoria Laboratory                NaN
# 20             mg/L  ISWS Peoria Laboratory                NaN
# 21             mg/L  ISWS Peoria Laboratory                NaN
# 22             mg/L  ISWS Peoria Laboratory                NaN
# 23             mg/L  ISWS Peoria Laboratory                NaN
# 24             mg/L  ISWS Peoria Laboratory                NaN
# 25             mg/L  ISWS Peoria Laboratory                NaN
# 26             mg/L  ISWS Peoria Laboratory                NaN
# 27             mg/L  ISWS Peoria Laboratory                NaN
# 28             mg/L  ISWS Peoria Laboratory                NaN
# 29             mg/L  ISWS Peoria Laboratory                NaN
# ...             ...                     ...                ...
# 100610         mg/L  ISWS Peoria Laboratory                NaN
# 100611         mg/L  ISWS Peoria Laboratory                NaN
# 100612         mg/L  ISWS Peoria Laboratory                NaN
# 100613         mg/L  ISWS Peoria Laboratory                NaN
# 100614         mg/L  ISWS Peoria Laboratory                NaN
# 100615         mg/L  ISWS Peoria Laboratory                NaN
# 100616         mg/L  ISWS Peoria Laboratory                NaN
# 100617         mg/L  ISWS Peoria Laboratory                NaN
# 100618         mg/L  ISWS Peoria Laboratory                NaN
# 100619         mg/L  ISWS Peoria Laboratory                NaN
# 100620         mg/L  ISWS Peoria Laboratory                NaN
# 100621         mg/L  ISWS Peoria Laboratory                NaN
# 100622         mg/L  ISWS Peoria Laboratory                NaN
# 100623         mg/L  ISWS Peoria Laboratory                NaN
# 100624         mg/L  ISWS Peoria Laboratory                NaN
# 100625         mg/L  ISWS Peoria Laboratory                NaN
# 100626         mg/L  ISWS Peoria Laboratory                NaN
# 100627         mg/L  ISWS Peoria Laboratory                NaN
# 100628         mg/L  ISWS Peoria Laboratory                NaN
# 100629         mg/L  ISWS Peoria Laboratory                NaN
# 100630         mg/L  ISWS Peoria Laboratory                NaN
# 100631         mg/L  ISWS Peoria Laboratory                NaN
# 100632         mg/L  ISWS Peoria Laboratory                NaN
# 100633         mg/L  ISWS Peoria Laboratory                NaN
# 100634         mg/L  ISWS Peoria Laboratory                NaN
# 100635         mg/L  ISWS Peoria Laboratory                NaN
# 100636         mg/L  ISWS Peoria Laboratory                NaN
# 100637         mg/L  ISWS Peoria Laboratory                NaN
# 100638         mg/L  ISWS Peoria Laboratory                NaN
# 100639         mg/L  ISWS Peoria Laboratory                NaN
#
#         CharacteristicID           Chr_Name ANLMTH_ID  \
# 0                     18  Oxygen, Dissolved        67
# 1                     18  Oxygen, Dissolved        67
# 2                     18  Oxygen, Dissolved        67
# 3                     18  Oxygen, Dissolved        67
# 4                     18  Oxygen, Dissolved        67
# 5                     18  Oxygen, Dissolved        67
# 6                     18  Oxygen, Dissolved        67
# 7                     18  Oxygen, Dissolved        67
# 8                     18  Oxygen, Dissolved        67
# 9                     18  Oxygen, Dissolved        67
# 10                    18  Oxygen, Dissolved        67
# 11                    18  Oxygen, Dissolved        67
# 12                    18  Oxygen, Dissolved        67
# 13                    18  Oxygen, Dissolved        67
# 14                    18  Oxygen, Dissolved        67
# 15                    18  Oxygen, Dissolved        67
# 16                    18  Oxygen, Dissolved        67
# 17                    18  Oxygen, Dissolved        67
# 18                    18  Oxygen, Dissolved        67
# 19                    18  Oxygen, Dissolved        67
# 20                    18  Oxygen, Dissolved        67
# 21                    18  Oxygen, Dissolved        67
# 22                    18  Oxygen, Dissolved        67
# 23                    18  Oxygen, Dissolved        67
# 24                    18  Oxygen, Dissolved        67
# 25                    18  Oxygen, Dissolved        67
# 26                    18  Oxygen, Dissolved        67
# 27                    18  Oxygen, Dissolved        67
# 28                    18  Oxygen, Dissolved        67
# 29                    18  Oxygen, Dissolved        67
# ...                  ...                ...       ...
# 100610                18  Oxygen, Dissolved        67
# 100611                18  Oxygen, Dissolved        67
# 100612                18  Oxygen, Dissolved        67
# 100613                18  Oxygen, Dissolved        67
# 100614                18  Oxygen, Dissolved        67
# 100615                18  Oxygen, Dissolved        67
# 100616                18  Oxygen, Dissolved        67
# 100617                18  Oxygen, Dissolved        67
# 100618                18  Oxygen, Dissolved        67
# 100619                18  Oxygen, Dissolved        67
# 100620                18  Oxygen, Dissolved        67
# 100621                18  Oxygen, Dissolved        67
# 100622                18  Oxygen, Dissolved        67
# 100623                18  Oxygen, Dissolved        67
# 100624                18  Oxygen, Dissolved        67
# 100625                18  Oxygen, Dissolved        67
# 100626                18  Oxygen, Dissolved        67
# 100627                18  Oxygen, Dissolved        67
# 100628                18  Oxygen, Dissolved        67
# 100629                18  Oxygen, Dissolved        67
# 100630                18  Oxygen, Dissolved        67
# 100631                18  Oxygen, Dissolved        67
# 100632                18  Oxygen, Dissolved        67
# 100633                18  Oxygen, Dissolved        67
# 100634                18  Oxygen, Dissolved        67
# 100635                18  Oxygen, Dissolved        67
# 100636                18  Oxygen, Dissolved        67
# 100637                18  Oxygen, Dissolved        67
# 100638                18  Oxygen, Dissolved        67
# 100639                18  Oxygen, Dissolved        67
#
#                             ANLMTH_Name          ANLMTH_Desc  \
# 0       Oxygen (Dissolved) by Volumetry  Azide modification
# 1       Oxygen (Dissolved) by Volumetry  Azide modification
# 2       Oxygen (Dissolved) by Volumetry  Azide modification
# 3       Oxygen (Dissolved) by Volumetry  Azide modification
# 4       Oxygen (Dissolved) by Volumetry  Azide modification
# 5       Oxygen (Dissolved) by Volumetry  Azide modification
# 6       Oxygen (Dissolved) by Volumetry  Azide modification
# 7       Oxygen (Dissolved) by Volumetry  Azide modification
# 8       Oxygen (Dissolved) by Volumetry  Azide modification
# 9       Oxygen (Dissolved) by Volumetry  Azide modification
# 10      Oxygen (Dissolved) by Volumetry  Azide modification
# 11      Oxygen (Dissolved) by Volumetry  Azide modification
# 12      Oxygen (Dissolved) by Volumetry  Azide modification
# 13      Oxygen (Dissolved) by Volumetry  Azide modification
# 14      Oxygen (Dissolved) by Volumetry  Azide modification
# 15      Oxygen (Dissolved) by Volumetry  Azide modification
# 16      Oxygen (Dissolved) by Volumetry  Azide modification
# 17      Oxygen (Dissolved) by Volumetry  Azide modification
# 18      Oxygen (Dissolved) by Volumetry  Azide modification
# 19      Oxygen (Dissolved) by Volumetry  Azide modification
# 20      Oxygen (Dissolved) by Volumetry  Azide modification
# 21      Oxygen (Dissolved) by Volumetry  Azide modification
# 22      Oxygen (Dissolved) by Volumetry  Azide modification
# 23      Oxygen (Dissolved) by Volumetry  Azide modification
# 24      Oxygen (Dissolved) by Volumetry  Azide modification
# 25      Oxygen (Dissolved) by Volumetry  Azide modification
# 26      Oxygen (Dissolved) by Volumetry  Azide modification
# 27      Oxygen (Dissolved) by Volumetry  Azide modification
# 28      Oxygen (Dissolved) by Volumetry  Azide modification
# 29      Oxygen (Dissolved) by Volumetry  Azide modification
# ...                                 ...                  ...
# 100610  Oxygen (Dissolved) by Volumetry  Azide modification
# 100611  Oxygen (Dissolved) by Volumetry  Azide modification
# 100612  Oxygen (Dissolved) by Volumetry  Azide modification
# 100613  Oxygen (Dissolved) by Volumetry  Azide modification
# 100614  Oxygen (Dissolved) by Volumetry  Azide modification
# 100615  Oxygen (Dissolved) by Volumetry  Azide modification
# 100616  Oxygen (Dissolved) by Volumetry  Azide modification
# 100617  Oxygen (Dissolved) by Volumetry  Azide modification
# 100618  Oxygen (Dissolved) by Volumetry  Azide modification
# 100619  Oxygen (Dissolved) by Volumetry  Azide modification
# 100620  Oxygen (Dissolved) by Volumetry  Azide modification
# 100621  Oxygen (Dissolved) by Volumetry  Azide modification
# 100622  Oxygen (Dissolved) by Volumetry  Azide modification
# 100623  Oxygen (Dissolved) by Volumetry  Azide modification
# 100624  Oxygen (Dissolved) by Volumetry  Azide modification
# 100625  Oxygen (Dissolved) by Volumetry  Azide modification
# 100626  Oxygen (Dissolved) by Volumetry  Azide modification
# 100627  Oxygen (Dissolved) by Volumetry  Azide modification
# 100628  Oxygen (Dissolved) by Volumetry  Azide modification
# 100629  Oxygen (Dissolved) by Volumetry  Azide modification
# 100630  Oxygen (Dissolved) by Volumetry  Azide modification
# 100631  Oxygen (Dissolved) by Volumetry  Azide modification
# 100632  Oxygen (Dissolved) by Volumetry  Azide modification
# 100633  Oxygen (Dissolved) by Volumetry  Azide modification
# 100634  Oxygen (Dissolved) by Volumetry  Azide modification
# 100635  Oxygen (Dissolved) by Volumetry  Azide modification
# 100636  Oxygen (Dissolved) by Volumetry  Azide modification
# 100637  Oxygen (Dissolved) by Volumetry  Azide modification
# 100638  Oxygen (Dissolved) by Volumetry  Azide modification
# 100639  Oxygen (Dissolved) by Volumetry  Azide modification
#
#                                                ANLMTH_Ref
# 0       American Public Health Association. 1975. Stan...
# 1       American Public Health Association. 1975. Stan...
# 2       American Public Health Association. 1975. Stan...
# 3       American Public Health Association. 1975. Stan...
# 4       American Public Health Association. 1975. Stan...
# 5       American Public Health Association. 1975. Stan...
# 6       American Public Health Association. 1975. Stan...
# 7       American Public Health Association. 1975. Stan...
# 8       American Public Health Association. 1975. Stan...
# 9       American Public Health Association. 1975. Stan...
# 10      American Public Health Association. 1975. Stan...
# 11      American Public Health Association. 1975. Stan...
# 12      American Public Health Association. 1975. Stan...
# 13      American Public Health Association. 1975. Stan...
# 14      American Public Health Association. 1975. Stan...
# 15      American Public Health Association. 1975. Stan...
# 16      American Public Health Association. 1975. Stan...
# 17      American Public Health Association. 1975. Stan...
# 18      American Public Health Association. 1975. Stan...
# 19      American Public Health Association. 1975. Stan...
# 20      American Public Health Association. 1975. Stan...
# 21      American Public Health Association. 1975. Stan...
# 22      American Public Health Association. 1975. Stan...
# 23      American Public Health Association. 1975. Stan...
# 24      American Public Health Association. 1975. Stan...
# 25      American Public Health Association. 1975. Stan...
# 26      American Public Health Association. 1975. Stan...
# 27      American Public Health Association. 1975. Stan...
# 28      American Public Health Association. 1975. Stan...
# 29      American Public Health Association. 1975. Stan...
# ...                                                   ...
# 100610  American Public Health Association. 1975. Stan...
# 100611  American Public Health Association. 1975. Stan...
# 100612  American Public Health Association. 1975. Stan...
# 100613  American Public Health Association. 1975. Stan...
# 100614  American Public Health Association. 1975. Stan...
# 100615  American Public Health Association. 1975. Stan...
# 100616  American Public Health Association. 1975. Stan...
# 100617  American Public Health Association. 1975. Stan...
# 100618  American Public Health Association. 1975. Stan...
# 100619  American Public Health Association. 1975. Stan...
# 100620  American Public Health Association. 1975. Stan...
# 100621  American Public Health Association. 1975. Stan...
# 100622  American Public Health Association. 1975. Stan...
# 100623  American Public Health Association. 1975. Stan...
# 100624  American Public Health Association. 1975. Stan...
# 100625  American Public Health Association. 1975. Stan...
# 100626  American Public Health Association. 1975. Stan...
# 100627  American Public Health Association. 1975. Stan...
# 100628  American Public Health Association. 1975. Stan...
# 100629  American Public Health Association. 1975. Stan...
# 100630  American Public Health Association. 1975. Stan...
# 100631  American Public Health Association. 1975. Stan...
# 100632  American Public Health Association. 1975. Stan...
# 100633  American Public Health Association. 1975. Stan...
# 100634  American Public Health Association. 1975. Stan...
# 100635  American Public Health Association. 1975. Stan...
# 100636  American Public Health Association. 1975. Stan...
# 100637  American Public Health Association. 1975. Stan...
# 100638  American Public Health Association. 1975. Stan...
# 100639  American Public Health Association. 1975. Stan...
#
# [100640 rows x 38 columns]

# %%
df['ResultValue(mg/L)'][:100640]
# Out:
# 0     13.00
# 1     11.40
# 2     12.45
# 3     13.10
# 4     12.45
# 5     12.35
# 6     12.95
# 7     11.40
# 8     12.35
# 9     12.30
# 10    12.10
# 11    11.40
# 12    11.95
# 13    11.95
# 14    11.80
# ...
# 100625     6.75
# 100626     3.65
# 100627     6.10
# 100628     5.35
# 100629     4.80
# 100630     5.94
# 100631     4.24
# 100632     4.60
# 100633     4.30
# 100634     5.33
# 100635     7.50
# 100636     8.40
# 100637    11.30
# 100638    10.04
# 100639    11.10
# Name: ResultValue(mg/L), Length: 100640, dtype: float64

# %%
df['ResultValue(mg/L)'].plot()

# %%
df.plot(x='Date', y='ResultValue(mg/L)')

# %%
plt.title('Yearly Dissolved Oxygen from 1965-1999 in Peoria, IL')
plt.xlabel('Date')
plt.ylabel('ResultValue(mg/L)')

# %%
plt.axhline(y=4, xmin=0, xmax=4, linewidth=3, color = 'r',label='Dangerous Dissolved Oxygen Level for Aquatic Life')

# %%
plt.legend()
plt.show()
